# %% [markdown]
# ### Step 1: Download Data from: http://data.insideairbnb.com/

# %%
from urllib.parse import urlparse
import requests
import gzip
from io import BytesIO
import os
import pandas as pd  # Import pandas
import re  # For regular expressions

def clean_state_name(state):
    """Cleans the state name by replacing dashes with spaces and removing unwanted characters."""
    state = state.replace('-', ' ')  # Replace dashes with spaces
    state = re.sub(r'[^a-zA-Z0-9 ]', '', state)  # Remove all characters that are not alphabets, digits, or spaces
    return state

def download_and_process_file(url, base_save_directory):
    # Extracting details from the URL
    parsed_url = urlparse(url)
    path_parts = parsed_url.path.split('/')
    
    # Debugging: Print path_parts
    print("URL path parts:", path_parts)

    # Check if path_parts has enough elements
    if len(path_parts) < 6:
        raise ValueError("URL does not have the expected number of parts")

    try:
        date_part = path_parts[4]
        year, mo = date_part.split('-')[0], date_part.split('-')[1]
        state = clean_state_name(path_parts[2])  # Clean the state name
        city = path_parts[3]
        country = path_parts[1]
        file_type = path_parts[-1].split('.')[0]
    except IndexError as e:
        raise IndexError(f"Error parsing URL: {url}, {e}")

    # Download the file
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception(f"Failed to download file: {url}")

    # Extract the file
    with gzip.open(BytesIO(response.content), 'rb') as f_in:
        file_content = f_in.read()

    # Determine the save directory based on file type
    type_directories = {
        'calendar': 'calendar',
        'listings': 'listings',
        'reviews': 'reviews'
    }
    save_directory = os.path.join(base_save_directory, type_directories.get(file_type, 'other'))

    # Ensure the save directory exists
    os.makedirs(save_directory, exist_ok=True)

    # Save the extracted file
    new_filename = f"{year}_{mo}_{city}_{state}_{country}_{file_type}.csv"
    new_filepath = os.path.join(save_directory, new_filename)
    with open(new_filepath, 'wb') as f_out:
        f_out.write(file_content)
    
    return new_filepath

# Base directory to save the processed files
base_save_directory = "./all"

# Read URLs from a CSV file
links_df = pd.read_csv('links.csv')  # Make sure 'links.csv' is in the correct path

# Process the URLs
processed_files = []
for url in links_df.iloc[:, 0]:  # Assume URLs are in the first column
    try:
        processed_file = download_and_process_file(url, base_save_directory)
        processed_files.append(processed_file)
    except Exception as e:
        print(f"Error processing {url}: {e}")
        
# List of processed files
print(processed_files)
# Out:
# URL path parts: ['', 'argentina', 'ciudad-aut%C3%B3noma-de-buenos-aires', 'buenos-aires', '2021-12-25', 'data', 'listings.csv.gz']
# URL path parts: ['', 'argentina', 'ciudad-aut%C3%B3noma-de-buenos-aires', 'buenos-aires', '2021-12-25', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'australia', 'nsw', 'northern-rivers', '2021-12-12', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'australia', 'nsw', 'northern-rivers', '2021-12-12', 'data', 'listings.csv.gz']
# URL path parts: ['', 'australia', 'nsw', 'northern-rivers', '2021-12-12', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'australia', 'nsw', 'sydney', '2021-12-07', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'australia', 'nsw', 'sydney', '2021-12-07', 'data', 'listings.csv.gz']
# URL path parts: ['', 'australia', 'nsw', 'sydney', '2021-12-07', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'australia', 'sa', 'barossa-valley', '2021-12-24', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'australia', 'sa', 'barossa-valley', '2021-12-24', 'data', 'listings.csv.gz']
# URL path parts: ['', 'australia', 'sa', 'barossa-valley', '2021-12-24', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'australia', 'tas', 'tasmania', '2021-12-05', 'data', 'calendar.csv.gz']
# Error processing http://data.insideairbnb.com
 'data', 'calendar.csv.gz']
# URL path parts: ['', 'germany', 'bv', 'munich', '2021-12-24', 'data', 'listings.csv.gz']
# URL path parts: ['', 'germany', 'bv', 'munich', '2021-12-24', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'greece', 'attica', 'athens', '2021-12-23', 'data', 'calendar.csv.gz']
# Error processing http://data.insideairbnb.com/greece/attica/athens/2021-12-23/data/calendar.csv.gz: Failed to download file: http://data.insideairbnb.com/greece/attica/athens/2021-12-23/data/calendar.csv.gz
# URL path parts: ['', 'greece', 'attica', 'athens', '2021-12-23', 'data', 'listings.csv.gz']
# Error processing http://data.insideairbnb.com/greece/attica/athens/2021-12-23/data/listings.csv.gz: Failed to download file: http://data.insideairbnb.com/greece/attica/athens/2021-12-23/data/listings.csv.gz
# URL path parts: ['', 'greece', 'attica', 'athens', '2021-12-23', 'data', 'reviews.csv.gz']
# Error processing http://data.insideairbnb.com/greece/attica/athens/2021-12-23/data/reviews.csv.gz: Failed to download file: http://data.insideairbnb.com/greece/attica/athens/2021-12-23/data/reviews.csv.gz
# URL path parts: ['', 'greece', 'central-macedonia', 'thessaloniki', '2021-12-23', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'greece', 'central-macedonia', 'thessaloniki', '2021-12-23', 'data', 'listings.csv.gz']
# URL path parts: ['', 'greece', 'central-macedonia', 'thessaloniki', '2021-12-23', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'greece', 'crete', 'crete', '2021-12-26', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'greece', 'crete', 'crete', '2021-12-26', 'data', 'listings.csv.gz']
# URL path parts: ['', 'greece', 'crete', 'crete', '2021-12-26', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'greece', 'south-aegean', 'south-aegean', '2021-12-18', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'greece', 'south-aegean', 'south-aegean', '2021-12-18', 'data', 'listings.csv.gz']
# URL path parts: ['', 'greece', 'south-aegean', 'south-aegean', '2021-12-18', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'ireland', 'leinster', 'dublin', '2021-12-08', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'ireland', 'leinster', 'dublin', '2021-12-08', 'data', 'listings.csv.gz']
# URL path parts: ['', 'ireland', 'leinster', 'dublin', '2021-12-08', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'italy', 'campania', 'naples', '2021-12-15', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'italy', 'campania', 'naples', '2021-12-15', 'data', 'listings.csv.gz']
# URL path parts: ['', 'italy', 'campania', 'naples', '2021-12-15', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'italy', 'emilia-romagna', 'bologna', '2021-12-17', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'italy', 'emilia-romagna', 'bologna', '2021-12-17', 'data', 'listings.csv.gz']
# URL path parts: ['', 'italy', 'emilia-romagna', 'bologna', '2021-12-17', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'italy', 'lazio', 'rome', '2021-12-08', 'data', 'calendar.csv.gz']
# Error processing http://data.insideairbnb.com/italy/lazio/rome/2021-12-08/data/calendar.csv.gz: Failed to download file: http://data.insideairbnb.com/italy/lazio/rome/2021-12-08/data/calendar.csv.gz
# URL path parts: ['', 'italy', 'lazio', 'rome', '2021-12-08', 'data', 'listings.csv.gz']
# Error processing http://data.insideairbnb.com/italy/lazio/rome/2021-12-08/data/listings.csv.gz: Failed to download file: http://data.insideairbnb.com/italy/lazio/rome/2021-12-08/data/listings.csv.gz
# URL path parts: ['', 'italy', 'lazio', 'rome', '2021-12-08', 'data', 'reviews.csv.gz']
# Error processing http://data.insideairbnb.com/italy/lazio/rome/2021-12-08/data/reviews.csv.gz: Failed to download file: http://data.insideairbnb.com/italy/lazio/rome/2021-12-08/data/reviews.csv.gz
# URL path parts: ['', 'italy', 'lombardia', 'bergamo', '2021-12-30', 'data', 'calendar.csv.gz']
# URL path parts: ['', 'italy', 'lombardia', 'bergamo', '2021-12-30', 'data', 'listings.csv.gz']
# URL path parts: ['', 'italy', 'lombardia', 'bergamo', '2021-12-30', 'data', 'reviews.csv.gz']
# URL path parts: ['', 'italy', 'lombardy', 'milan', '2021-12-15', 'data', 'calendar.csv.gz']
# Error processing http://data.insideairbnb.com/italy/lombardy/milan/2021-12-15/data/calendar.csv.gz: Failed to download file: http://data.insideairbnb.com/italy/lombardy/milan/2021-12-15/data/calendar.csv.gz
# URL path parts: ['', 'italy', 'lombardy', 'milan', '2021-12-15', 'data', 'listings.csv.gz']
# Error processing http://data.insideairbnb.com/italy/lombardy/milan/2021-12-15/data/listings.csv.gz: Failed to download file: http://data.insideairbnb.com/italy/lombardy/milan/2021-12-15/data/listings.csv.gz
# URL path parts: ['', 'italy', 'lombardy', 'milan', '2021-12-15', 'data', 'reviews.csv.gz']
# Error processing http://data.insideairbnb.com/italy/lombardy/milan/2021-12-15/data/reviews.csv.gz: Failed to download file: http://data.insideairbnb.com/italy
# %%
import os
import pandas as pd

# Define the path to the 'all/calendar' directory
directory_path = './all/calendar'

# List the files in the directory
files = os.listdir(directory_path)

# Split each file name into components and create a DataFrame
data = []
for file in files:
    parts = file.replace('.csv', '').split('_')
    if len(parts) == 6:  # Ensure the file name has the correct number of parts
        year, mo, city, state, country, _ = parts
        data.append([year, mo, city, state, country, file])  # Include the original file name

# Create DataFrame
columns = ['year', 'mo', 'city', 'state', 'country', 'file_name']
df = pd.DataFrame(data, columns=columns)

# Create a unique identifier for each city-state-country combination
df['city_id'] = pd.factorize(df['city'] + '-' + df['state'] + '-' + df['country'])[0]

# Save the DataFrame as 'data_index.csv'
df.to_csv('./data_index.csv', index=False)

# %%
import pandas as pd
import os
from datetime import datetime
import re

# Setup and configurations
input_folder = './all/calendar'
output_folder = './clean/calendar'
index_file = './data_index.csv'
end_date_cutoff = datetime(2023, 12, 31)

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Read city information from index file
def read_city_index():
    print("Reading city index...")
    return pd.read_csv(index_file)

# Function to clean and convert price
def clean_price(price):
    if pd.isnull(price) or price == '':
        return None
    return float(price.strip('$').replace(',', ''))

# Function to convert availability
def convert_availability(available):
    return 1 if available in ['t', 'true'] else 0

# Process individual listings
def process_listing(city, listing_data):
    #print(f"Processing listing {listing_data.iloc[0]['listing_id']} for {city}...")
    listing_data['date'] = pd.to_datetime(listing_data['date'], format='%Y-%m-%d', errors='coerce')
    listing_data = listing_data[listing_data['date'] <= end_date_cutoff]
    listing_data['price'] = listing_data['price'].apply(clean_price)
    listing_data.dropna(subset=['price'], inplace=True)
    listing_data.drop(columns=['adjusted_price'], inplace=True)
    listing_data['available'] = listing_data['available'].apply(convert_availability)
    return listing_data

# Function to extract year and month from filename
def extract_year_month_from_filename(filename):
    match = re.search(r'\d{4}_\d{2}', filename)
    return datetime.strptime(match.group(), '%Y_%m') if match else None

# Process cities by listing_ids
def process_cities_by_listing(city, file_names):
    print(f"Starting processing for city: {city}")
    file_names = sorted(file_names, key=extract_year_month_from_filename, reverse=True)
    all_data = pd.DataFrame()
    for file in file_names:
        print(f"Reading data from file: {file}")
        data = pd.read_csv(f"{input_folder}/{file}")
        all_data = pd.concat([all_data, data])

    grouped_data = all_data.groupby('listing_id')
    processed_data = grouped_data.apply(lambda x: process_listing(city, x)).reset_index(drop=True)
    processed_data.to_csv(f"{output_folder}/Clean_{city}.csv", index=False)
    print(f"Finished processing for {city}.")

# Main script to process a batch of cities
def process_batch_of_cities(cities_batch):
    for city, file_names in cities_batch.items():
        output_path = f"{output_folder}/Clean_{city}.csv"
        if not os.path.exists(output_path):
            process_cities_by_listing(city, file_names)
        else:
            print(f"Skipped processing for {city} as cleaned data already exists.")

# Main script to process all cities
def main():
    print("Data cleaning process started.")
    city_info_df = read_city_index()
    cities_info = city_info_df.groupby('city')['file_name'].apply(list).to_dict()
    cities_batches = [dict(list(cities_info.items())[i:i + 6]) for i in range(0, len(cities_info), 6)]  # Split cities into batches of 6

    for batch in cities_batches:
        process_batch_of_cities(batch)
    print("Data cleaning process completed.")

if __name__ == "__main__":
    main()
# Out:
# Data cleaning process started.
# Reading city index...
# Skipped processing for albany as cleaned data already exists.
# Skipped processing for amsterdam as cleaned data already exists.
# Skipped processing for antwerp as cleaned data already exists.
# Skipped processing for asheville as cleaned data already exists.
# Skipped processing for athens as cleaned data already exists.
# Skipped processing for austin as cleaned data already exists.
# Skipped processing for bangkok as cleaned data already exists.
# Skipped processing for barcelona as cleaned data already exists.
# Skipped processing for barossa-valley as cleaned data already exists.
# Skipped processing for barwon-south-west-vic as cleaned data already exists.
# Skipped processing for beijing as cleaned data already exists.
# Skipped processing for belize as cleaned data already exists.
# Skipped processing for bergamo as cleaned data already exists.
# Skipped processing for berlin as cleaned data already exists.
# Skipped processing for bologna as cleaned data already exists.
# Skipped processing for bordeaux as cleaned data already exists.
# Starting processing for city: boston
# Reading data from file: 2023_09_boston_ma_united-states_calendar.csv
# Reading data from file: 2023_06_boston_ma_united-states_calendar.csv
# Reading data from file: 2023_03_boston_ma_united-states_calendar.csv
# Reading data from file: 2022_12_boston_ma_united-states_calendar.csv
# Reading data from file: 2022_09_boston_ma_united-states_calendar.csv
# Finished processing for boston.
# Starting processing for city: bozeman
# Reading data from file: 2023_11_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_10_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_09_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_08_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_07_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_06_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_05_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_04_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_03_bozeman_mt_united-states_calendar.csv
# Reading data from file: 2023_02_bozeman_mt_united-states_calendar.csv
# Finished processing for bozeman.
# Starting processing for city: bristol
# Reading data from file: 2023_09_bristol_england_united-kingdom_calendar.csv
# Reading data from file: 2023_06_bristol_england_united-kingdom_calendar.csv
# Reading data from file: 2023_03_bristol_england_united-kingdom_calendar.csv
# Reading data from file: 2022_12_bristol_england_united-kingdom_calendar.csv
# Reading data from file: 2022_09_bristol_england_united-kingdom_calendar.csv
# Finished processing for bristol.
# Starting processing for city: broward-county
# Reading data from file: 2023_09_broward-county_fl_united-states_calendar.csv
# Reading data from file: 2023_06_broward-county_fl_united-states_calendar.csv
# Reading data from file: 2023_03_broward-county_fl_united-states_calendar.csv
# Reading data from file: 2022_12_broward-county_fl_united-states_calendar.csv
# Reading data from file: 2022_09_broward-county_fl_united-states_calendar.csv
# Finished processing for broward-county.
# Starting processing for city: brussels
# Reading data from file: 2023_09_brussels_bru_belgium_calendar.csv
# Reading data from file: 2023_06_brussels_bru_belgium_calendar.csv
# Reading data from file: 2023_03_brussels_bru_belgium_calendar.csv
# Reading data from file: 2022_12_brussels_bru_belgium_calendar.csv
# Reading data from file: 2022_09_brussels_bru_belgium_calendar.csv
# Reading data from file: 2022_06_brussels_bru_belgium_calendar.csv
# Reading data from file: 2022_03_brussels_bru_belgium_calendar.csv
# Reading data from file: 2021_12_brussels_bru_belgium_calendar.csv
# Reading data from file: 2021_09_brussels_bru_belgium_calendar.csv
# Reading data from file: 2021_06_brussels_bru_belgium_calendar.csv
# Finished processing for brussels.
# Starting processing for city: buenos-aires
# Reading data from file: 2023_09_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Reading data from file: 2023_06_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Reading data from file: 2023_03_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Reading data from file: 2022_12_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Reading data from file: 2022_09_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Reading data from file: 2022_06_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Reading data from file: 2022_03_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Reading data from file: 2021_09_buenos-aires_ciudad autC3B3noma de buenos aires_argentina_calendar.csv
# Finished processing for buenos-aires.
# Starting processing for city: cambridge
# Reading data from file: 2023_09_cambridge_ma_united-states_calendar.csv
# Reading data from file: 2023_06_cambridge_ma_united-states_calendar.csv
# Reading data from file: 2023_03_cambridge_ma_united-states_calendar.csv
# Reading data from file: 2022_12_cambridge_ma_united-states_calendar.csv
# Reading data from file: 2022_09_cambridge_ma_united-states_calendar.csv
# Finished processing for cambridge.
# Starting processing for city: cape-town
# Reading data from file: 2023_09_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2023_06_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2023_03_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2022_12_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2022_09_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2022_06_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2022_03_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2021_12_cape-town_wc_south-africa_calendar.csv
# Reading data from file: 2021_09_cape-town_wc_south-africa_calendar.csv
# Finished processing for cape-town.
# Starting processing for city: chicago
# Reading data from file: 2023_09_chicago_il_united-states_calendar.csv
# Reading data from file: 2023_06_chicago_il_united-states_calendar.csv
# Reading data from file: 2023_03_chicago_il_united-states_calendar.csv
# Reading data from file: 2022_12_chicago_il_united-states_calendar.csv
# Reading data from file: 2022_09_chicago_il_united-states_calendar.csv
# Finished processing for chicago.
# Starting processing for city: clark-county-nv
# Reading data from file: 2023_09_clark-county-nv_nv_united-states_calendar.csv
# Reading data from file: 2023_06_clark-county-nv_nv_united-states_calendar.csv
# Reading data from file: 2023_03_clark-county-nv_nv_united-states_calendar.csv
# Reading data from file: 2022_12_clark-county-nv_nv_united-states_calendar.csv
# Reading data from file: 2022_09_clark-county-nv_nv_united-states_calendar.csv
# Finished processing for clark-county-nv.
# Starting processing for city: columbus
# Reading data from file: 2023_09_columbus_oh_united-states_calendar.csv
# Reading data from file: 2023_06_columbus_oh_united-states_calendar.csv
# Reading data from file: 2023_03_columbus_oh_united-states_calendar.csv
# Reading data from file: 2022_12_columbus_oh_united-states_calendar.csv
# Reading data from file: 2022_09_columbus_oh_united-states_calendar.csv
# Finished processing for columbus.
# Starting processing for city: copenhagen
# Reading data from file: 2023_09_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2023_06_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2023_03_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2022_12_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2022_09_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2022_06_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2022_03_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2021_12_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2021_09_copenhagen_hovedstaden_denmark_calendar.csv
# Reading data from file: 2021_06_copenhagen_hovedstaden_denmark_calendar.csv
# Finished processing for copenhagen.
# Starting processing for city: crete
# Reading data from file: 2023_09_crete_crete_greece_calendar.csv
# Reading data from file: 2023_06_crete_crete_greece_calendar.csv
# Reading data from file: 2023_03_crete_crete_greece_calendar.csv
# Reading data from file: 2022_12_crete_crete_greece_calendar.csv
# Reading data from file: 2022_09_crete_crete_greece_calendar.csv
# Reading data from file: 2022_06_crete_crete_greece_calendar.csv
# Reading data from file: 2022_03_crete_crete_greece_calendar.csv
# Reading data from file: 2021_12_crete_crete_greece_calendar.csv
# Reading data from file: 2021_09_crete_crete_greece_calendar.csv
# Finished processing for crete.
# Starting processing for city: dallas
# Reading data from file: 2023_10_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_09_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_08_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_07_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_06_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_05_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_04_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_03_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_02_dallas_tx_united-states_calendar.csv
# Reading data from file: 2023_01_dallas_tx_united-states_calendar.csv
# Reading data from file: 2022_12_dallas_tx_united-states_calendar.csv
# Reading data from file: 2022_11_dallas_tx_united-states_calendar.csv
# Reading data from file: 2022_10_dallas_tx_united-states_calendar.csv
# Reading data from file: 2022_09_dallas_tx_united-states_calendar.csv
# Finished processing for dallas.
# Starting processing for city: denver
# Reading data from file: 2023_09_denver_co_united-states_calendar.csv
# Reading data from file: 2023_06_denver_co_united-states_calendar.csv
# Reading data from file: 2023_03_denver_co_united-states_calendar.csv
# Reading data from file: 2022_12_denver_co_united-states_calendar.csv
# Reading data from file: 2022_09_denver_co_united-states_calendar.csv
# Finished processing for denver.
# Starting processing for city: dublin
# Reading data from file: 2023_09_dublin_leinster_ireland_calendar.csv
# Reading data from file: 2023_06_dublin_leinster_ireland_calendar.csv
# Reading data from file: 2023_03_dublin_leinster_ireland_calendar.csv
# Reading data from file: 2022_12_dublin_leinster_ireland_calendar.csv
# Reading data from file: 2022_09_dublin_leinster_ireland_calendar.csv
# Reading data from file: 2022_06_dublin_leinster_ireland_calendar.csv
# Reading data from file: 2022_03_dublin_leinster_ireland_calendar.csv
# Reading data from file: 2021_12_dublin_leinster_ireland_calendar.csv
# Finished processing for dublin.
# Starting processing for city: edinburgh
# Reading data from file: 2023_09_edinburgh_scotland_united-kingdom_calendar.csv
# Reading data from file: 2023_06_edinburgh_scotland_united-kingdom_calendar.csv
# Reading data from file: 2023_03_edinburgh_scotland_united-kingdom_calendar.csv
# Reading data from file: 2022_12_edinburgh_scotland_united-kingdom_calendar.csv
# Reading data from file: 2022_09_edinburgh_scotland_united-kingdom_calendar.csv
# Finished processing for edinburgh.
# Starting processing for city: euskadi
# Reading data from file: 2023_09_euskadi_pv_spain_calendar.csv
# Reading data from file: 2023_06_euskadi_pv_spain_calendar.csv
# Reading data from file: 2023_03_euskadi_pv_spain_calendar.csv
# Reading data from file: 2022_12_euskadi_pv_spain_calendar.csv
# Reading data from file: 2022_09_euskadi_pv_spain_calendar.csv
# Reading data from file: 2022_06_euskadi_pv_spain_calendar.csv
# Reading data from file: 2022_03_euskadi_pv_spain_calendar.csv
# Reading data from file: 2021_12_euskadi_pv_spain_calendar.csv
# Reading data from file: 2021_09_euskadi_pv_spain_calendar.csv
# Reading data from file: 2021_06_euskadi_pv_spain_calendar.csv
# Finished processing for euskadi.
# Starting processing for city: florence
# Reading data from file: 2023_09_florence_toscana_italy_calendar.csv
# Reading data from file: 2023_06_florence_toscana_italy_calendar.csv
# Reading data from file: 2023_03_florence_toscana_italy_calendar.csv
# Reading data from file: 2022_12_florence_toscana_italy_calendar.csv
# Reading data from file: 2022_09_florence_toscana_italy_calendar.csv
# Finished processing for florence.
# Starting processing for city: fort-worth
# Reading data from file: 2023_09_fort-worth_tx_united-states_calendar.csv
# Reading data from file: 2023_06_fort-worth_tx_united-states_calendar.csv
# Reading data from file: 2023_03_fort-worth_tx_united-states_calendar.csv
# Reading data from file: 2022_12_fort-worth_tx_united-states_calendar.csv
# Reading data from file: 2022_09_fort-worth_tx_united-states_calendar.csv
# Finished processing for fort-worth.
# Starting processing for city: geneva
# Reading data from file: 2023_09_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2023_06_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2023_03_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2022_12_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2022_09_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2022_06_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2022_03_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2021_12_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2021_09_geneva_geneva_switzerland_calendar.csv
# Reading data from file: 2021_06_geneva_geneva_switzerland_calendar.csv
# Finished processing for geneva.
# Starting processing for city: ghent
# Reading data from file: 2023_09_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2023_06_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2023_03_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2022_12_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2022_09_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2022_06_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2022_03_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2021_12_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2021_09_ghent_vlg_belgium_calendar.csv
# Reading data from file: 2021_06_ghent_vlg_belgium_calendar.csv
# Finished processing for ghent.
# Starting processing for city: girona
# Reading data from file: 2023_09_girona_catalonia_spain_calendar.csv
# Reading data from file: 2023_06_girona_catalonia_spain_calendar.csv
# Reading data from file: 2023_03_girona_catalonia_spain_calendar.csv
# Reading data from file: 2022_12_girona_catalonia_spain_calendar.csv
# Reading data from file: 2022_09_girona_catalonia_spain_calendar.csv
# Reading data from file: 2022_06_girona_catalonia_spain_calendar.csv
# Reading data from file: 2022_03_girona_catalonia_spain_calendar.csv
# Reading data from file: 2021_12_girona_catalonia_spain_calendar.csv
# Reading data from file: 2021_09_girona_catalonia_spain_calendar.csv
# Finished processing for girona.
# Starting processing for city: greater-manchester
# Reading data from file: 2023_09_greater-manchester_england_united-kingdom_calendar.csv
# Reading data from file: 2023_06_greater-manchester_england_united-kingdom_calendar.csv
# Reading data from file: 2023_03_greater-manchester_england_united-kingdom_calendar.csv
# Reading data from file: 2022_12_greater-manchester_england_united-kingdom_calendar.csv
# Reading data from file: 2022_09_greater-manchester_england_united-kingdom_calendar.csv
# Finished processing for greater-manchester.
# Starting processing for city: hawaii
# Reading data from file: 2023_09_hawaii_hi_united-states_calendar.csv
# Reading data from file: 2023_06_hawaii_hi_united-states_calendar.csv
# Reading data from file: 2023_03_hawaii_hi_united-states_calendar.csv
# Reading data from file: 2022_12_hawaii_hi_united-states_calendar.csv
# Reading data from file: 2022_09_hawaii_hi_united-states_calendar.csv
# Finished processing for hawaii.
# Starting processing for city: hong-kong
# Reading data from file: 2023_09_hong-kong_hk_china_calendar.csv
# Reading data from file: 2023_06_hong-kong_hk_china_calendar.csv
# Reading data from file: 2023_03_hong-kong_hk_china_calendar.csv
# Reading data from file: 2022_12_hong-kong_hk_china_calendar.csv
# Reading data from file: 2022_09_hong-kong_hk_china_calendar.csv
# Reading data from file: 2022_06_hong-kong_hk_china_calendar.csv
# Reading data from file: 2022_03_hong-kong_hk_china_calendar.csv
# Reading data from file: 2021_12_hong-kong_hk_china_calendar.csv
# Reading data from file: 2021_09_hong-kong_hk_china_calendar.csv
# Finished processing for hong-kong.
# Starting processing for city: istanbul
# Reading data from file: 2023_09_istanbul_marmara_turkey_calendar.csv
# Reading data from file: 2023_06_istanbul_marmara_turkey_calendar.csv
# Reading data from file: 2023_03_istanbul_marmara_turkey_calendar.csv
# Reading data from file: 2022_12_istanbul_marmara_turkey_calendar.csv
# Reading data from file: 2022_09_istanbul_marmara_turkey_calendar.csv
# Reading data from file: 2022_06_istanbul_marmara_turkey_calendar.csv
# Reading data from file: 2022_03_istanbul_marmara_turkey_calendar.csv
# Finished processing for istanbul.
# Starting processing for city: jersey-city
# Reading data from file: 2023_09_jersey-city_nj_united-states_calendar.csv
# Reading data from file: 2023_06_jersey-city_nj_united-states_calendar.csv
# Reading data from file: 2023_03_jersey-city_nj_united-states_calendar.csv
# Reading data from file: 2022_12_jersey-city_nj_united-states_calendar.csv
# Reading data from file: 2022_09_jersey-city_nj_united-states_calendar.csv
# Finished processing for jersey-city.
# Starting processing for city: lisbon
# Reading data from file: 2023_09_lisbon_lisbon_portugal_calendar.csv
# Reading data from file: 2023_06_lisbon_lisbon_portugal_calendar.csv
# Reading data from file: 2023_03_lisbon_lisbon_portugal_calendar.csv
# Reading data from file: 2022_12_lisbon_lisbon_portugal_calendar.csv
# Reading data from file: 2022_09_lisbon_lisbon_portugal_calendar.csv
# Finished processing for lisbon.
# Starting processing for city: london
# Reading data from file: 2023_09_london_england_united-kingdom_calendar.csv
# Reading data from file: 2023_06_london_england_united-kingdom_calendar.csv
# Reading data from file: 2023_03_london_england_united-kingdom_calendar.csv
# Reading data from file: 2022_12_london_england_united-kingdom_calendar.csv
# Reading data from file: 2022_09_london_england_united-kingdom_calendar.csv
# Finished processing for london.
# Starting processing for city: los-angeles
# Reading data from file: 2023_09_los-angeles_ca_united-states_calendar.csv
# Reading data from file: 2023_06_los-angeles_ca_united-states_calendar.csv
# Reading data from file: 2023_03_los-angeles_ca_united-states_calendar.csv
# Reading data from file: 2022_12_los-angeles_ca_united-states_calendar.csv
# Reading data from file: 2022_09_los-angeles_ca_united-states_calendar.csv
# Finished processing for los-angeles.
# Starting processing for city: lyon
# Reading data from file: 2023_09_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2023_06_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2023_03_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2022_12_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2022_09_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2022_06_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2022_03_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2021_12_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2021_09_lyon_auvergne rhone alpes_france_calendar.csv
# Reading data from file: 2021_06_lyon_auvergne rhone alpes_france_calendar.csv
# Finished processing for lyon.
# Starting processing for city: madrid
# Reading data from file: 2023_09_madrid_comunidad de madrid_spain_calendar.csv
# Reading data from file: 2023_06_madrid_comunidad de madrid_spain_calendar.csv
# Reading data from file: 2023_03_madrid_comunidad de madrid_spain_calendar.csv
# Reading data from file: 2022_12_madrid_comunidad de madrid_spain_calendar.csv
# Reading data from file: 2022_09_madrid_comunidad de madrid_spain_calendar.csv
# Finished processing for madrid.
# Starting processing for city: malaga
# Reading data from file: 2023_09_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2023_06_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2023_03_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2022_12_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2022_09_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2022_06_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2022_03_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2021_12_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2021_09_malaga_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2021_06_malaga_andalucC3ADa_spain_calendar.csv
# Finished processing for malaga.
# Starting processing for city: mallorca
# Reading data from file: 2023_09_mallorca_islas baleares_spain_calendar.csv
# Reading data from file: 2023_06_mallorca_islas baleares_spain_calendar.csv
# Reading data from file: 2023_03_mallorca_islas baleares_spain_calendar.csv
# Reading data from file: 2022_12_mallorca_islas baleares_spain_calendar.csv
# Reading data from file: 2022_09_mallorca_islas baleares_spain_calendar.csv
# Finished processing for mallorca.
# Starting processing for city: melbourne
# Reading data from file: 2023_09_melbourne_vic_australia_calendar.csv
# Reading data from file: 2023_06_melbourne_vic_australia_calendar.csv
# Reading data from file: 2023_03_melbourne_vic_australia_calendar.csv
# Reading data from file: 2022_12_melbourne_vic_australia_calendar.csv
# Reading data from file: 2022_09_melbourne_vic_australia_calendar.csv
# Reading data from file: 2022_06_melbourne_vic_australia_calendar.csv
# Reading data from file: 2022_03_melbourne_vic_australia_calendar.csv
# Reading data from file: 2021_12_melbourne_vic_australia_calendar.csv
# Reading data from file: 2021_09_melbourne_vic_australia_calendar.csv
# Reading data from file: 2021_06_melbourne_vic_australia_calendar.csv
# Finished processing for melbourne.
# Starting processing for city: menorca
# Reading data from file: 2023_09_menorca_islas baleares_spain_calendar.csv
# Reading data from file: 2023_06_menorca_islas baleares_spain_calendar.csv
# Reading data from file: 2023_03_menorca_islas baleares_spain_calendar.csv
# Reading data from file: 2022_12_menorca_islas baleares_spain_calendar.csv
# Reading data from file: 2022_09_menorca_islas baleares_spain_calendar.csv
# Finished processing for menorca.
# Starting processing for city: mexico-city
# Reading data from file: 2023_09_mexico-city_df_mexico_calendar.csv
# Reading data from file: 2023_06_mexico-city_df_mexico_calendar.csv
# Reading data from file: 2023_03_mexico-city_df_mexico_calendar.csv
# Reading data from file: 2022_12_mexico-city_df_mexico_calendar.csv
# Finished processing for mexico-city.
# Starting processing for city: mid-north-coast
# Reading data from file: 2023_11_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_10_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_09_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_08_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_07_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_06_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_05_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_04_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_03_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_02_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2023_01_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2022_12_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2022_11_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2022_10_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2022_09_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2022_08_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2022_07_mid-north-coast_nsw_australia_calendar.csv
# Reading data from file: 2022_06_mid-north-coast_nsw_australia_calendar.csv
# Finished processing for mid-north-coast.
# Starting processing for city: milan
# Reading data from file: 2023_09_milan_lombardy_italy_calendar.csv
# Reading data from file: 2023_06_milan_lombardy_italy_calendar.csv
# Reading data from file: 2023_03_milan_lombardy_italy_calendar.csv
# Reading data from file: 2022_12_milan_lombardy_italy_calendar.csv
# Finished processing for milan.
# Starting processing for city: montreal
# Reading data from file: 2023_10_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_09_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_08_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_07_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_06_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_05_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_04_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_03_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_02_montreal_qc_canada_calendar.csv
# Reading data from file: 2023_01_montreal_qc_canada_calendar.csv
# Reading data from file: 2022_12_montreal_qc_canada_calendar.csv
# Reading data from file: 2022_11_montreal_qc_canada_calendar.csv
# Reading data from file: 2022_10_montreal_qc_canada_calendar.csv
# Reading data from file: 2022_09_montreal_qc_canada_calendar.csv
# Reading data from file: 2022_08_montreal_qc_canada_calendar.csv
# Reading data from file: 2022_07_montreal_qc_canada_calendar.csv
# Finished processing for montreal.
# Starting processing for city: mornington-peninsula
# Reading data from file: 2023_09_mornington-peninsula_vic_australia_calendar.csv
# Reading data from file: 2023_06_mornington-peninsula_vic_australia_calendar.csv
# Reading data from file: 2023_03_mornington-peninsula_vic_australia_calendar.csv
# Reading data from file: 2022_12_mornington-peninsula_vic_australia_calendar.csv
# Reading data from file: 2022_09_mornington-peninsula_vic_australia_calendar.csv
# Reading data from file: 2022_06_mornington-peninsula_vic_australia_calendar.csv
# Finished processing for mornington-peninsula.
# Starting processing for city: munich
# Reading data from file: 2023_09_munich_bv_germany_calendar.csv
# Reading data from file: 2023_06_munich_bv_germany_calendar.csv
# Reading data from file: 2023_03_munich_bv_germany_calendar.csv
# Reading data from file: 2022_12_munich_bv_germany_calendar.csv
# Reading data from file: 2022_09_munich_bv_germany_calendar.csv
# Reading data from file: 2022_06_munich_bv_germany_calendar.csv
# Reading data from file: 2022_03_munich_bv_germany_calendar.csv
# Reading data from file: 2021_12_munich_bv_germany_calendar.csv
# Reading data from file: 2021_09_munich_bv_germany_calendar.csv
# Reading data from file: 2021_06_munich_bv_germany_calendar.csv
# Finished processing for munich.
# Starting processing for city: naples
# Reading data from file: 2023_09_naples_campania_italy_calendar.csv
# Reading data from file: 2023_06_naples_campania_italy_calendar.csv
# Reading data from file: 2023_03_naples_campania_italy_calendar.csv
# Reading data from file: 2022_12_naples_campania_italy_calendar.csv
# Reading data from file: 2022_09_naples_campania_italy_calendar.csv
# Reading data from file: 2022_06_naples_campania_italy_calendar.csv
# Reading data from file: 2022_03_naples_campania_italy_calendar.csv
# Reading data from file: 2021_12_naples_campania_italy_calendar.csv
# Reading data from file: 2021_09_naples_campania_italy_calendar.csv
# Reading data from file: 2021_06_naples_campania_italy_calendar.csv
# Finished processing for naples.
# Starting processing for city: nashville
# Reading data from file: 2023_09_nashville_tn_united-states_calendar.csv
# Reading data from file: 2023_06_nashville_tn_united-states_calendar.csv
# Reading data from file: 2023_03_nashville_tn_united-states_calendar.csv
# Reading data from file: 2022_12_nashville_tn_united-states_calendar.csv
# Reading data from file: 2022_09_nashville_tn_united-states_calendar.csv
# Finished processing for nashville.
# Starting processing for city: new-brunswick
# Reading data from file: 2023_09_new-brunswick_nb_canada_calendar.csv
# Reading data from file: 2023_06_new-brunswick_nb_canada_calendar.csv
# Reading data from file: 2023_03_new-brunswick_nb_canada_calendar.csv
# Reading data from file: 2022_12_new-brunswick_nb_canada_calendar.csv
# Reading data from file: 2022_09_new-brunswick_nb_canada_calendar.csv
# Reading data from file: 2022_06_new-brunswick_nb_canada_calendar.csv
# Finished processing for new-brunswick.
# Starting processing for city: new-orleans
# Reading data from file: 2023_09_new-orleans_la_united-states_calendar.csv
# Reading data from file: 2023_06_new-orleans_la_united-states_calendar.csv
# Reading data from file: 2023_03_new-orleans_la_united-states_calendar.csv
# Reading data from file: 2022_12_new-orleans_la_united-states_calendar.csv
# Reading data from file: 2022_09_new-orleans_la_united-states_calendar.csv
# Finished processing for new-orleans.
# Starting processing for city: new-york-city
# Reading data from file: 2023_11_new-york-city_ny_united-states_calendar.csv
# C:\Users\yirsu\AppData\Local\Temp\ipykernel_8492\135682862.py:66: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   process_cities_by_listing(city, file_names)
# Reading data from file: 2023_10_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_09_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_08_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_07_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_06_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_05_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_04_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_03_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_02_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2023_01_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2022_12_new-york-city_ny_united-states_calendar.csv
# Reading data from file: 2022_09_new-york-city_ny_united-states_calendar.csv
# Finished processing for new-york-city.
# Starting processing for city: newark
# Reading data from file: 2023_09_newark_nj_united-states_calendar.csv
# Reading data from file: 2023_06_newark_nj_united-states_calendar.csv
# Reading data from file: 2023_03_newark_nj_united-states_calendar.csv
# Reading data from file: 2022_12_newark_nj_united-states_calendar.csv
# Reading data from file: 2022_09_newark_nj_united-states_calendar.csv
# Finished processing for newark.
# Starting processing for city: northern-rivers
# Reading data from file: 2023_09_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2023_06_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2023_03_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2022_12_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2022_09_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2022_06_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2022_03_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2021_12_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2021_09_northern-rivers_nsw_australia_calendar.csv
# Reading data from file: 2021_06_northern-rivers_nsw_australia_calendar.csv
# Finished processing for northern-rivers.
# Starting processing for city: oakland
# Reading data from file: 2023_09_oakland_ca_united-states_calendar.csv
# Reading data from file: 2023_06_oakland_ca_united-states_calendar.csv
# Reading data from file: 2023_03_oakland_ca_united-states_calendar.csv
# Reading data from file: 2022_12_oakland_ca_united-states_calendar.csv
# Reading data from file: 2022_09_oakland_ca_united-states_calendar.csv
# Finished processing for oakland.
# Starting processing for city: oslo
# Reading data from file: 2023_09_oslo_oslo_norway_calendar.csv
# Reading data from file: 2023_06_oslo_oslo_norway_calendar.csv
# Reading data from file: 2023_03_oslo_oslo_norway_calendar.csv
# Reading data from file: 2022_12_oslo_oslo_norway_calendar.csv
# Reading data from file: 2022_09_oslo_oslo_norway_calendar.csv
# Reading data from file: 2022_06_oslo_oslo_norway_calendar.csv
# Reading data from file: 2022_03_oslo_oslo_norway_calendar.csv
# Reading data from file: 2021_12_oslo_oslo_norway_calendar.csv
# Reading data from file: 2021_09_oslo_oslo_norway_calendar.csv
# Reading data from file: 2021_06_oslo_oslo_norway_calendar.csv
# Finished processing for oslo.
# Starting processing for city: pacific-grove
# Reading data from file: 2023_09_pacific-grove_ca_united-states_calendar.csv
# Reading data from file: 2023_06_pacific-grove_ca_united-states_calendar.csv
# Reading data from file: 2023_03_pacific-grove_ca_united-states_calendar.csv
# Reading data from file: 2022_12_pacific-grove_ca_united-states_calendar.csv
# Reading data from file: 2022_09_pacific-grove_ca_united-states_calendar.csv
# Finished processing for pacific-grove.
# Starting processing for city: paris
# Reading data from file: 2023_09_paris_ile de france_france_calendar.csv
# Reading data from file: 2023_06_paris_ile de france_france_calendar.csv
# Reading data from file: 2023_03_paris_ile de france_france_calendar.csv
# Finished processing for paris.
# Starting processing for city: pays-basque
# Reading data from file: 2023_09_pays-basque_pyrC3A9nC3A9es atlantiques_france_calendar.csv
quebec-city_qc_canada_calendar.csv
# Reading data from file: 2022_08_quebec-city_qc_canada_calendar.csv
# Reading data from file: 2022_07_quebec-city_qc_canada_calendar.csv
# Finished processing for quebec-city.
# Starting processing for city: rhode-island
# Reading data from file: 2023_09_rhode-island_ri_united-states_calendar.csv
# Reading data from file: 2023_06_rhode-island_ri_united-states_calendar.csv
# Reading data from file: 2023_03_rhode-island_ri_united-states_calendar.csv
# Reading data from file: 2022_12_rhode-island_ri_united-states_calendar.csv
# Reading data from file: 2022_09_rhode-island_ri_united-states_calendar.csv
# Finished processing for rhode-island.
# Starting processing for city: riga
# Reading data from file: 2023_09_riga_riga_latvia_calendar.csv
# Reading data from file: 2023_06_riga_riga_latvia_calendar.csv
# Reading data from file: 2023_03_riga_riga_latvia_calendar.csv
# Reading data from file: 2022_12_riga_riga_latvia_calendar.csv
# Reading data from file: 2022_09_riga_riga_latvia_calendar.csv
# Reading data from file: 2022_06_riga_riga_latvia_calendar.csv
# Reading data from file: 2022_03_riga_riga_latvia_calendar.csv
# Reading data from file: 2021_12_riga_riga_latvia_calendar.csv
# Reading data from file: 2021_09_riga_riga_latvia_calendar.csv
# Reading data from file: 2021_06_riga_riga_latvia_calendar.csv
# Finished processing for riga.
# Starting processing for city: rio-de-janeiro
# Reading data from file: 2023_09_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2023_06_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2023_03_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2022_12_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2022_09_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2022_06_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2022_03_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2021_12_rio-de-janeiro_rj_brazil_calendar.csv
# Reading data from file: 2021_09_rio-de-janeiro_rj_brazil_calendar.csv
# Finished processing for rio-de-janeiro.
# Starting processing for city: rochester
# Reading data from file: 2023_10_rochester_ny_united-states_calendar.csv
# Finished processing for rochester.
# Starting processing for city: rome
# Reading data from file: 2023_09_rome_lazio_italy_calendar.csv
# Reading data from file: 2023_06_rome_lazio_italy_calendar.csv
# Reading data from file: 2023_03_rome_lazio_italy_calendar.csv
# Reading data from file: 2022_12_rome_lazio_italy_calendar.csv
# Finished processing for rome.
# Starting processing for city: rotterdam
# Reading data from file: 2023_09_rotterdam_south holland_the-netherlands_calendar.csv
# Reading data from file: 2023_06_rotterdam_south holland_the-netherlands_calendar.csv
# Reading data from file: 2023_03_rotterdam_south holland_the-netherlands_calendar.csv
# Reading data from file: 2022_12_rotterdam_south holland_the-netherlands_calendar.csv
# Reading data from file: 2022_09_rotterdam_south holland_the-netherlands_calendar.csv
# Reading data from file: 2022_06_rotterdam_south holland_the-netherlands_calendar.csv
# Reading data from file: 2022_03_rotterdam_south holland_the-netherlands_calendar.csv
# Finished processing for rotterdam.
# Starting processing for city: salem-or
# Reading data from file: 2023_09_salem-or_or_united-states_calendar.csv
# Reading data from file: 2023_06_salem-or_or_united-states_calendar.csv
# Reading data from file: 2023_03_salem-or_or_united-states_calendar.csv
# Reading data from file: 2022_12_salem-or_or_united-states_calendar.csv
# Reading data from file: 2022_09_salem-or_or_united-states_calendar.csv
# Finished processing for salem-or.
# Starting processing for city: san-diego
# Reading data from file: 2023_09_san-diego_ca_united-states_calendar.csv
# Reading data from file: 2023_06_san-diego_ca_united-states_calendar.csv
# Reading data from file: 2023_03_san-diego_ca_united-states_calendar.csv
# Reading data from file: 2022_12_san-diego_ca_united-states_calendar.csv
# Reading data from file: 2022_09_san-diego_ca_united-states_calendar.csv
# Finished processing for san-diego.
# Starting processing for city: san-francisco
# Reading data from file: 2023_09_san-francisco_ca_united-states_calendar.csv
# Reading data from file: 2023_06_san-francisco_ca_united-states_calendar.csv
# Reading data from file: 2023_03_san-francisco_ca_united-states_calendar.csv
# Reading data from file: 2022_12_san-francisco_ca_united-states_calendar.csv
# Reading data from file: 2022_09_san-francisco_ca_united-states_calendar.csv
# Finished processing for san-francisco.
# Starting processing for city: san-mateo-county
# Reading data from file: 2023_09_san-mateo-county_ca_united-states_calendar.csv
# Reading data from file: 2023_06_san-mateo-county_ca_united-states_calendar.csv
# Reading data from file: 2023_03_san-mateo-county_ca_united-states_calendar.csv
# Reading data from file: 2022_12_san-mateo-county_ca_united-states_calendar.csv
# Reading data from file: 2022_09_san-mateo-county_ca_united-states_calendar.csv
# Finished processing for san-mateo-county.
# Starting processing for city: santa-clara-county
# Reading data from file: 2023_09_santa-clara-county_ca_united-states_calendar.csv
# Reading data from file: 2023_06_santa-clara-county_ca_united-states_calendar.csv
# Reading data from file: 2023_03_santa-clara-county_ca_united-states_calendar.csv
# Reading data from file: 2022_12_santa-clara-county_ca_united-states_calendar.csv
# Reading data from file: 2022_09_santa-clara-county_ca_united-states_calendar.csv
# Finished processing for santa-clara-county.
# Starting processing for city: santa-cruz-county
# Reading data from file: 2023_09_santa-cruz-county_ca_united-states_calendar.csv
# Reading data from file: 2023_06_santa-cruz-county_ca_united-states_calendar.csv
# Reading data from file: 2023_03_santa-cruz-county_ca_united-states_calendar.csv
# Reading data from file: 2022_12_santa-cruz-county_ca_united-states_calendar.csv
# Reading data from file: 2022_09_santa-cruz-county_ca_united-states_calendar.csv
# Finished processing for santa-cruz-county.
# Starting processing for city: santiago
# Reading data from file: 2023_09_santiago_rm_chile_calendar.csv
# Reading data from file: 2023_06_santiago_rm_chile_calendar.csv
# Reading data from file: 2023_03_santiago_rm_chile_calendar.csv
# Reading data from file: 2022_12_santiago_rm_chile_calendar.csv
# Reading data from file: 2022_09_santiago_rm_chile_calendar.csv
# Reading data from file: 2022_06_santiago_rm_chile_calendar.csv
# Reading data from file: 2022_03_santiago_rm_chile_calendar.csv
# Reading data from file: 2021_12_santiago_rm_chile_calendar.csv
# Reading data from file: 2021_09_santiago_rm_chile_calendar.csv
# Finished processing for santiago.
# Starting processing for city: seattle
# Reading data from file: 2023_09_seattle_wa_united-states_calendar.csv
# Reading data from file: 2023_06_seattle_wa_united-states_calendar.csv
# Reading data from file: 2023_03_seattle_wa_united-states_calendar.csv
# Reading data from file: 2022_12_seattle_wa_united-states_calendar.csv
# Reading data from file: 2022_09_seattle_wa_united-states_calendar.csv
# Finished processing for seattle.
# Starting processing for city: sevilla
# Reading data from file: 2023_09_sevilla_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2023_06_sevilla_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2023_03_sevilla_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2022_12_sevilla_andalucC3ADa_spain_calendar.csv
# Reading data from file: 2022_09_sevilla_andalucC3ADa_spain_calendar.csv
# Finished processing for sevilla.
# Starting processing for city: shanghai
# Reading data from file: 2023_09_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2023_06_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2023_03_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2022_12_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2022_09_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2022_06_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2022_03_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2021_12_shanghai_shanghai_china_calendar.csv
# Reading data from file: 2021_09_shanghai_shanghai_china_calendar.csv
# Finished processing for shanghai.
# Starting processing for city: sicily
# Reading data from file: 2023_09_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2023_06_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2023_03_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2022_12_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2022_09_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2022_06_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2022_03_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2021_12_sicily_sicilia_italy_calendar.csv
# Reading data from file: 2021_09_sicily_sicilia_italy_calendar.csv
# Finished processing for sicily.
# Starting processing for city: singapore
# Reading data from file: 2023_09_singapore_sg_singapore_calendar.csv
# Reading data from file: 2023_06_singapore_sg_singapore_calendar.csv
# Reading data from file: 2023_03_singapore_sg_singapore_calendar.csv
# Reading data from file: 2022_12_singapore_sg_singapore_calendar.csv
# Reading data from file: 2022_09_singapore_sg_singapore_calendar.csv
# Reading data from file: 2022_06_singapore_sg_singapore_calendar.csv
# Reading data from file: 2022_03_singapore_sg_singapore_calendar.csv
# Reading data from file: 2021_12_singapore_sg_singapore_calendar.csv
# Reading data from file: 2021_09_singapore_sg_singapore_calendar.csv
# Reading data from file: 2021_06_singapore_sg_singapore_calendar.csv
# Finished processing for singapore.
# Starting processing for city: south-aegean
# Reading data from file: 2023_09_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2023_06_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2023_03_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2022_12_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2022_09_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2022_06_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2022_03_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2021_12_south-aegean_south aegean_greece_calendar.csv
# Reading data from file: 2021_09_south-aegean_south aegean_greece_calendar.csv
# Finished processing for south-aegean.
# Starting processing for city: stockholm
# Reading data from file: 2023_09_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2023_06_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2023_03_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2022_12_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2022_09_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2022_06_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2022_03_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2021_12_stockholm_stockholms lC3A4n_sweden_calendar.csv
# Reading data from file: 2021_09_stockholm_stockholms lC3A4n_sweden_calendar.csv
#
trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2023_06_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2023_03_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2022_12_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2022_09_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2022_06_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2022_03_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2021_12_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Reading data from file: 2021_09_trentino_trentino alto adige sC3BCdtirol_italy_calendar.csv
# Finished processing for trentino.
# Starting processing for city: twin-cities-msa
# Reading data from file: 2023_09_twin-cities-msa_mn_united-states_calendar.csv
# Reading data from file: 2023_06_twin-cities-msa_mn_united-states_calendar.csv
# Reading data from file: 2023_03_twin-cities-msa_mn_united-states_calendar.csv
# Reading data from file: 2022_12_twin-cities-msa_mn_united-states_calendar.csv
# Reading data from file: 2022_09_twin-cities-msa_mn_united-states_calendar.csv
# Finished processing for twin-cities-msa.
# Starting processing for city: valencia
# Reading data from file: 2023_09_valencia_vc_spain_calendar.csv
# Reading data from file: 2023_06_valencia_vc_spain_calendar.csv
# Reading data from file: 2023_03_valencia_vc_spain_calendar.csv
# Reading data from file: 2022_12_valencia_vc_spain_calendar.csv
# Reading data from file: 2022_09_valencia_vc_spain_calendar.csv
# Finished processing for valencia.
# Starting processing for city: vancouver
# Reading data from file: 2023_09_vancouver_bc_canada_calendar.csv
# Reading data from file: 2023_06_vancouver_bc_canada_calendar.csv
# Reading data from file: 2023_03_vancouver_bc_canada_calendar.csv
# Reading data from file: 2022_12_vancouver_bc_canada_calendar.csv
# Reading data from file: 2022_09_vancouver_bc_canada_calendar.csv
# Finished processing for vancouver.
# Starting processing for city: vaud
# Reading data from file: 2023_11_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_10_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_09_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_08_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_07_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_06_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_05_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_04_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_03_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_02_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2023_01_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_12_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_11_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_10_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_09_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_08_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_07_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_06_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_05_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_04_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_03_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_02_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2022_01_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2021_12_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2021_11_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2021_10_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2021_09_vaud_vd_switzerland_calendar.csv
# Reading data from file: 2021_06_vaud_vd_switzerland_calendar.csv
# Finished processing for vaud.
# Starting processing for city: venice
# Reading data from file: 2023_09_venice_veneto_italy_calendar.csv
# Reading data from file: 2023_06_venice_veneto_italy_calendar.csv
# Reading data from file: 2023_03_venice_veneto_italy_calendar.csv
# Reading data from file: 2022_12_venice_veneto_italy_calendar.csv
# Reading data from file: 2022_09_venice_veneto_italy_calendar.csv
# Reading data from file: 2022_06_venice_veneto_italy_calendar.csv
# Reading data from file: 2022_03_venice_veneto_italy_calendar.csv
# Reading data from file: 2021_12_venice_veneto_italy_calendar.csv
# Reading data from file: 2021_09_venice_veneto_italy_calendar.csv
# Finished processing for venice.
# Starting processing for city: victoria
# Reading data from file: 2023_09_victoria_bc_canada_calendar.csv
# Reading data from file: 2023_06_victoria_bc_canada_calendar.csv
# Reading data from file: 2023_03_victoria_bc_canada_calendar.csv
# Reading data from file: 2022_12_victoria_bc_canada_calendar.csv
# Reading data from file: 2022_09_victoria_bc_canada_calendar.csv
# Reading data from file: 2022_06_victoria_bc_canada_calendar.csv
# Finished processing for victoria.
# Starting processing for city: vienna
# Reading data from file: 2023_09_vienna_vienna_austria_calendar.csv
# Reading data from file: 2023_06_vienna_vienna_austria_calendar.csv
# Reading data from file: 2023_03_vienna_vienna_austria_calendar.csv
# Reading data from file: 2022_12_vienna_vienna_austria_calendar.csv
# Reading data from file: 2022_09_vienna_vienna_austria_calendar.csv
# Finished processing for vienna.
# Starting processing for city: washington-dc
# Reading data from file: 2023_09_washington-dc_dc_united-states_calendar.csv
# Reading data from file: 2023_06_washington-dc_dc_united-states_calendar.csv
# Reading data from file: 2023_03_washington-dc_dc_united-states_calendar.csv
# Reading data from file: 2022_12_washington-dc_dc_united-states_calendar.csv
# Reading data from file: 2022_09_washington-dc_dc_united-states_calendar.csv
# Finished processing for washington-dc.
# Starting processing for city: western-australia
# Reading data from file: 2023_09_western-australia_wa_australia_calendar.csv
# Reading data from file: 2023_06_western-australia_wa_australia_calendar.csv
# Reading data from file: 2023_03_western-australia_wa_australia_calendar.csv
# Reading data from file: 2022_12_western-australia_wa_australia_calendar.csv
# Finished processing for western-australia.
# Starting processing for city: winnipeg
# Reading data from file: 2023_09_winnipeg_mb_canada_calendar.csv
# Reading data from file: 2023_06_winnipeg_mb_canada_calendar.csv
# Reading data from file: 2023_03_winnipeg_mb_canada_calendar.csv
# Reading data from file: 2022_12_winnipeg_mb_canada_calendar.csv
# Reading data from file: 2022_09_winnipeg_mb_canada_calendar.csv
# Finished processing for winnipeg.
# Starting processing for city: zurich
# Reading data from file: 2023_09_zurich_zC3BCrich_switzerland_calendar.csv
# Reading data from file: 2023_06_zurich_zC3BCrich_switzerland_calendar.csv
# Reading data from file: 2023_03_zurich_zC3BCrich_switzerland_calendar.csv
# Reading data from file: 2022_12_zurich_zC3BCrich_switzerland_calendar.csv
# Reading data from file: 2022_09_zurich_zC3BCrich_switzerland_calendar.csv
# Reading data from file: 2022_06_zurich_zC3BCrich_switzerland_calendar.csv
# Reading data from file: 2022_03_zurich_zC3BCrich_switzerland_calendar.csv
# Finished processing for zurich.
# Data cleaning process completed.

# %%
import os
import pandas as pd

input_folder = './clean/calendar/'

# Function to remove duplicates while keeping the first occurrence
def remove_duplicates(file_path):
    # Read the data
    data = pd.read_csv(file_path)
    
    # Convert 'date' to datetime if it's not already
    data['date'] = pd.to_datetime(data['date'])

    # Remove duplicates while keeping the first occurrence
    cleaned_data = data.drop_duplicates(subset=['listing_id', 'date'], keep='first')

    # Save the cleaned data back to the same file
    cleaned_data.to_csv(file_path, index=False)
    print(f"Processed and saved cleaned data to {file_path}")

# Process all CSV files in the directory
for file_name in os.listdir(input_folder):
    if file_name.endswith('.csv'):
        file_path = input_folder + file_name
        remove_duplicates(file_path)

print("All files have been processed and duplicates removed.")
# Out:
# Processed and saved cleaned data to ./clean/calendar/Clean_albany.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_amsterdam.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_antwerp.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_asheville.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_athens.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_austin.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_bangkok.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_barcelona.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_barossa-valley.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_barwon-south-west-vic.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_beijing.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_belize.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_bergamo.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_berlin.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_bologna.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_bordeaux.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_boston.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_bozeman.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_bristol.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_broward-county.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_brussels.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_buenos-aires.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_cambridge.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_cape-town.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_chicago.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_clark-county-nv.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_columbus.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_copenhagen.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_crete.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_dallas.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_denver.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_dublin.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_edinburgh.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_euskadi.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_florence.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_fort-worth.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_geneva.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_ghent.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_girona.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_greater-manchester.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_hawaii.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_hong-kong.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_istanbul.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_jersey-city.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_lisbon.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_london.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_los-angeles.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_lyon.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_madrid.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_malaga.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_mallorca.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_melbourne.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_menorca.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_mexico-city.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_mid-north-coast.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_milan.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_montreal.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_mornington-peninsula.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_munich.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_naples.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_nashville.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_new-brunswick.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_new-orleans.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_new-york-city.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_newark.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_northern-rivers.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_oakland.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_oslo.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_pacific-grove.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_paris.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_pays-basque.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_portland.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_porto.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_prague.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_puglia.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_quebec-city.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_rhode-island.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_riga.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_rio-de-janeiro.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_rochester.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_rome.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_rotterdam.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_salem-or.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_san-diego.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_san-francisco.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_san-mateo-county.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_santa-clara-county.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_santa-cruz-county.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_santiago.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_seattle.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_sevilla.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_shanghai.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_sicily.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_singapore.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_south-aegean.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_stockholm.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_sydney.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_taipei.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_tasmania.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_the-hague.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_thessaloniki.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_tokyo.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_toronto.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_trentino.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_twin-cities-msa.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_valencia.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_vancouver.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_vaud.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_venice.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_victoria.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_vienna.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_washington-dc.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_western-australia.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_winnipeg.csv
# Processed and saved cleaned data to ./clean/calendar/Clean_zurich.csv
# All files have been processed and duplicates removed.

# %%
import os
import csv
from datetime import date, timedelta
from forex_python.converter import CurrencyRates

# List of country and currency ISO pairs
data = [
    ("belgium", "EUR"), ("australia", "AUD"), ("belize", "BZD"), ("italy", "EUR"),
    ("denmark", "DKK"), ("spain", "EUR"), ("switzerland", "CHF"), ("france", "EUR"),
    ("germany", "EUR"), ("norway", "NOK"), ("latvia", "EUR"), ("singapore", "SGD"),
    ("sweden", "SEK"), ("taiwan", "TWD"), ("greece", "EUR"), ("thailand", "THB"),
    ("china", "CNY"), ("argentina", "ARS"), ("south-africa", "ZAR"), ("portugal", "EUR"),
    ("brazil", "BRL"), ("chile", "CLP"), ("ireland", "EUR"), ("turkey", "TRY"),
    ("the-netherlands", "EUR"), ("canada", "CAD"), ("united-states", "EUR"),
    ("united-kingdom", "EUR"), ("czech-republic", "CZK"), ("austria", "EUR"),
    ("mexico", "MXN"), ("japan", "JPY")
]

# Extract unique ISO codes
unique_iso_codes = sorted(set([iso for _, iso in data]))

# Create a directory for exchange rates if it doesn't exist
folder_path = "./exchange_rate"
os.makedirs(folder_path, exist_ok=True)

# Initialize CurrencyRates
c = CurrencyRates()

# Keep track of ISO codes that have already been processed
processed_isos = set()

# Fetch exchange rate data and save to CSV files
for iso in unique_iso_codes:
    # Skip if this ISO has already been processed
    if iso in processed_isos:
        continue

    file_path = os.path.join(folder_path, f"{iso}.csv")
    success = True  # Flag to indicate if fetching is successful

    with open(file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Date", f"Exchange Rate to 1 USD ({iso})"])
        
        # Define the date range
        start_date = date(2021, 12, 1)
        end_date = date(2023, 12, 31)
        current_date = start_date
        
        while current_date <= end_date and success:
            try:
                # Fetch the exchange rate for the current date
                rate = c.get_rate('USD', iso, current_date)
                writer.writerow([current_date, rate])
            except Exception as e:
                print(f"Error fetching data for {iso} on {current_date}: {e}")
                success = False  # Set success to False if any error occurs
            # Move to the next day
            current_date += timedelta(days=1)

    if success:
        print(f"Data for {iso} successfully saved to {file_path}")
    else:
        os.remove(file_path)  # Remove the file if there was an error
        print(f"Data for {iso} was not saved due to errors. File {file_path} has been removed.")

    processed_isos.add(iso)

print("Exchange rate data fetching process completed.")
# Out:
# Error fetching data for ARS on 2021-12-01: Currency Rate USD => ARS not available for Date 2021-12-01
# Data for ARS was not saved due to errors. File ./exchange_rate\ARS.csv has been removed.
# Data for AUD successfully saved to ./exchange_rate\AUD.csv
# Data for BRL successfully saved to ./exchange_rate\BRL.csv
# Error fetching data for BZD on 2021-12-01: Currency Rate USD => BZD not available for Date 2021-12-01
# Data for BZD was not saved due to errors. File ./exchange_rate\BZD.csv has been removed.
# Data for CAD successfully saved to ./exchange_rate\CAD.csv
# Data for CHF successfully saved to ./exchange_rate\CHF.csv
# Error fetching data for CLP on 2021-12-01: Currency Rate USD => CLP not available for Date 2021-12-01
# Data for CLP was not saved due to errors. File ./exchange_rate\CLP.csv has been removed.
# Data for CNY successfully saved to ./exchange_rate\CNY.csv
# Data for CZK successfully saved to ./exchange_rate\CZK.csv
# Data for DKK successfully saved to ./exchange_rate\DKK.csv
# Error fetching data for EUR on 2022-12-22: Currency Rate USD => EUR not available for Date 2022-12-22
# Data for EUR was not saved due to errors. File ./exchange_rate\EUR.csv has been removed.
# Data for GBP successfully saved to ./exchange_rate\GBP.csv
# Data for JPY successfully saved to ./exchange_rate\JPY.csv
# Data for MXN successfully saved to ./exchange_rate\MXN.csv
# Data for NOK successfully saved to ./exchange_rate\NOK.csv
# Data for SEK successfully saved to ./exchange_rate\SEK.csv
# Data for SGD successfully saved to ./exchange_rate\SGD.csv
# Data for THB successfully saved to ./exchange_rate\THB.csv
# Data for TRY successfully saved to ./exchange_rate\TRY.csv
# Error fetching data for TWD on 2021-12-01: Currency Rate USD => TWD not available for Date 2021-12-01
# Data for TWD was not saved due to errors. File ./exchange_rate\TWD.csv has been removed.
# Data for ZAR successfully saved to ./exchange_rate\ZAR.csv
# Exchange rate data fetching process completed.

# %%
import os
import pandas as pd
from pathlib import Path
from datetime import datetime

# Function to load and process each file
def process_file(file_path, rates, city_currency_map):
    # Load data
    df = pd.read_csv(file_path)
    df['date'] = pd.to_datetime(df['date'])
    df.sort_values(by=['listing_id', 'date'], inplace=True)
    
    # Task 1: Count price changes
    df['price_changed'] = df.groupby('listing_id')['price'].diff().ne(0)
    df['price_change_count'] = df.groupby('listing_id')['price_changed'].cumsum()

    # Task 2: Count availability changes from 0 to 1
    df['availability_changed'] = df['available'].diff().eq(1) & df['listing_id'].eq(df['listing_id'].shift())
    df['change_in_availability'] = df.groupby('listing_id')['availability_changed'].cumsum()

    # Task 3: Calculate monthly and quarterly availability rates
    df['month'] = df['date'].dt.month
    df['quarter'] = df['date'].dt.quarter
    monthly_availability = df.groupby(['listing_id', 'month'])['available'].sum().reset_index(name='monthly_availability_count')
    quarterly_availability = df.groupby(['listing_id', 'quarter'])['available'].sum().reset_index(name='quarterly_availability_count')
    df = df.merge(monthly_availability, on=['listing_id', 'month'], how='left')
    df = df.merge(quarterly_availability, on=['listing_id', 'quarter'], how='left')

    # Task 4: Calculate monthly weekend availability
    df['day_of_week'] = df['date'].dt.dayofweek  # 0=Monday, 6=Sunday
    df['is_weekend'] = df['day_of_week'].isin([5, 6]).astype(int)  # Convert to 0/1 dummy variable
    df['weekend_available'] = df['available'] * df['is_weekend']

    # Ensure 'month' column reflects the actual month-year combination
    df['year_month'] = df['date'].dt.to_period('M')

    # Sum weekend availability for each month
    df['monthly_weekend_availability'] = df.groupby(['listing_id', 'year_month'])['weekend_available'].transform('sum')
    # Once used, you can drop the 'year_month' column as it's no longer needed
    df.drop('year_month', axis=1, inplace=True)

    # Task 5: Convert price to USD and create 'price_usd'
    city_name = file_path.split('_')[1].split('.')[0].lower()
    currency = city_currency_map.get(city_name)
    if currency and currency != 'USD':
        exchange_rate_file = f'./exchange_rate/{currency}.csv'
        if os.path.exists(exchange_rate_file):
            exchange_rates = load_exchange_rates(exchange_rate_file)
            df = apply_exchange_rate(df, exchange_rates, f'Exchange Rate to 1 USD ({currency})')
        else:
            print(f"No exchange rate data found for currency: {currency}")
    else:
        df['price_usd'] = df['price']  # For USD, copy the price

    # Save the processed data
    new_file_path = file_path.replace('/calendar/', '/calendar2/')
    df.to_csv(new_file_path, index=False)
    print(f"Processed and saved to {new_file_path}")

# Load exchange rates
def load_exchange_rates(file_path):
    rates = pd.read_csv(file_path, parse_dates=['Date'])
    rates['Date'] = rates['Date'].dt.date
    rates.set_index('Date', inplace=True)
    return rates

# Apply exchange rate to convert price to USD
def apply_exchange_rate(df, rates, currency_column):
    df['date'] = df['date'].dt.date
    df = df.merge(rates, left_on='date', right_index=True, how='left')
    df['price_usd'] = (df['price'] / df[currency_column]).round(3)
    df.drop(columns=[currency_column], inplace=True)
    return df

# Load the data index to map cities to currencies
data_index = pd.read_csv('./data_index.csv')
city_currency_map = dict(zip(data_index['city'].str.lower(), data_index['currency_iso']))

# Create the output directory if it doesn't exist
Path('./clean/calendar2/').mkdir(parents=True, exist_ok=True)

# Process each file in the directory
for file_name in os.listdir('./clean/calendar/'):
    if file_name.endswith('.csv'):
        file_path = f'./clean/calendar/{file_name}'
        process_file(file_path, None, city_currency_map)  # Pass None for rates as it's loaded in process_file
# Out:
# Processed and saved to ./clean/calendar2/Clean_albany.csv
# Processed and saved to ./clean/calendar2/Clean_amsterdam.csv
# Processed and saved to ./clean/calendar2/Clean_antwerp.csv
# Processed and saved to ./clean/calendar2/Clean_asheville.csv
# Processed and saved to ./clean/calendar2/Clean_athens.csv
# Processed and saved to ./clean/calendar2/Clean_austin.csv
# Processed and saved to ./clean/calendar2/Clean_bangkok.csv
# Processed and saved to ./clean/calendar2/Clean_barcelona.csv
# Processed and saved to ./clean/calendar2/Clean_barossa-valley.csv
# Processed and saved to ./clean/calendar2/Clean_barwon-south-west-vic.csv
# Processed and saved to ./clean/calendar2/Clean_beijing.csv
# Processed and saved to ./clean/calendar2/Clean_belize.csv
# Processed and saved to ./clean/calendar2/Clean_bergamo.csv
# Processed and saved to ./clean/calendar2/Clean_berlin.csv
# Processed and saved to ./clean/calendar2/Clean_bologna.csv
# Processed and saved to ./clean/calendar2/Clean_bordeaux.csv
# Processed and saved to ./clean/calendar2/Clean_boston.csv
# Processed and saved to ./clean/calendar2/Clean_bozeman.csv
# Processed and saved to ./clean/calendar2/Clean_bristol.csv
# Processed and saved to ./clean/calendar2/Clean_broward-county.csv
# Processed and saved to ./clean/calendar2/Clean_brussels.csv
# Processed and saved to ./clean/calendar2/Clean_buenos-aires.csv
# Processed and saved to ./clean/calendar2/Clean_cambridge.csv
# Processed and saved to ./clean/calendar2/Clean_cape-town.csv
# Processed and saved to ./clean/calendar2/Clean_chicago.csv
# Processed and saved to ./clean/calendar2/Clean_clark-county-nv.csv
# Processed and saved to ./clean/calendar2/Clean_columbus.csv
# Processed and saved to ./clean/calendar2/Clean_copenhagen.csv
# Processed and saved to ./clean/calendar2/Clean_crete.csv
# Processed and saved to ./clean/calendar2/Clean_dallas.csv
# Processed and saved to ./clean/calendar2/Clean_denver.csv
# Processed and saved to ./clean/calendar2/Clean_dublin.csv
# Processed and saved to ./clean/calendar2/Clean_edinburgh.csv
# Processed and saved to ./clean/calendar2/Clean_euskadi.csv
# Processed and saved to ./clean/calendar2/Clean_florence.csv
# Processed and saved to ./clean/calendar2/Clean_fort-worth.csv
# Processed and saved to ./clean/calendar2/Clean_geneva.csv
# Processed and saved to ./clean/calendar2/Clean_ghent.csv
# Processed and saved to ./clean/calendar2/Clean_girona.csv
# Processed and saved to ./clean/calendar2/Clean_greater-manchester.csv
# Processed and saved to ./clean/calendar2/Clean_hawaii.csv
# Processed and saved to ./clean/calendar2/Clean_hong-kong.csv
# Processed and saved to ./clean/calendar2/Clean_istanbul.csv
# Processed and saved to ./clean/calendar2/Clean_jersey-city.csv
# Processed and saved to ./clean/calendar2/Clean_lisbon.csv
# Processed and saved to ./clean/calendar2/Clean_london.csv
# Processed and saved to ./clean/calendar2/Clean_los-angeles.csv
# Processed and saved to ./clean/calendar2/Clean_lyon.csv
# Processed and saved to ./clean/calendar2/Clean_madrid.csv
# Processed and saved to ./clean/calendar2/Clean_malaga.csv
# Processed and saved to ./clean/calendar2/Clean_mallorca.csv
# Processed and saved to ./clean/calendar2/Clean_melbourne.csv
# Processed and saved to ./clean/calendar2/Clean_menorca.csv
# Processed and saved to ./clean/calendar2/Clean_mexico-city.csv
# Processed and saved to ./clean/calendar2/Clean_mid-north-coast.csv
# Processed and saved to ./clean/calendar2/Clean_milan.csv
# Processed and saved to ./clean/calendar2/Clean_montreal.csv
# Processed and saved to ./clean/calendar2/Clean_mornington-peninsula.csv
# Processed and saved to ./clean/calendar2/Clean_munich.csv
# Processed and saved to ./clean/calendar2/Clean_naples.csv
# Processed and saved to ./clean/calendar2/Clean_nashville.csv
# Processed and saved to ./clean/calendar2/Clean_new-brunswick.csv
# Processed and saved to ./clean/calendar2/Clean_new-orleans.csv
# Processed and saved to ./clean/calendar2/Clean_new-york-city.csv
# Processed and saved to ./clean/calendar2/Clean_newark.csv
# Processed and saved to ./clean/calendar2/Clean_northern-rivers.csv
# Processed and saved to ./clean/calendar2/Clean_oakland.csv
# Processed and saved to ./clean/calendar2/Clean_oslo.csv
# Processed and saved to ./clean/calendar2/Clean_pacific-grove.csv
# Processed and saved to ./clean/calendar2/Clean_paris.csv
# Processed and saved to ./clean/calendar2/Clean_pays-basque.csv
# Processed and saved to ./clean/calendar2/Clean_portland.csv
# Processed and saved to ./clean/calendar2/Clean_porto.csv
# Processed and saved to ./clean/calendar2/Clean_prague.csv
# Processed and saved to ./clean/calendar2/Clean_puglia.csv
# Processed and saved to ./clean/calendar2/Clean_quebec-city.csv
# Processed and saved to ./clean/calendar2/Clean_rhode-island.csv
# Processed and saved to ./clean/calendar2/Clean_riga.csv
# Processed and saved to ./clean/calendar2/Clean_rio-de-janeiro.csv
# Processed and saved to ./clean/calendar2/Clean_rochester.csv
# Processed and saved to ./clean/calendar2/Clean_rome.csv
# Processed and saved to ./clean/calendar2/Clean_rotterdam.csv
# Processed and saved to ./clean/calendar2/Clean_salem-or.csv
# Processed and saved to ./clean/calendar2/Clean_san-diego.csv
# Processed and saved to ./clean/calendar2/Clean_san-francisco.csv
# Processed and saved to ./clean/calendar2/Clean_san-mateo-county.csv
# Processed and saved to ./clean/calendar2/Clean_santa-clara-county.csv
# Processed and saved to ./clean/calendar2/Clean_santa-cruz-county.csv
# Processed and saved to ./clean/calendar2/Clean_santiago.csv
# Processed and saved to ./clean/calendar2/Clean_seattle.csv
# Processed and saved to ./clean/calendar2/Clean_sevilla.csv
# Processed and saved to ./clean/calendar2/Clean_shanghai.csv
# Processed and saved to ./clean/calendar2/Clean_sicily.csv
# Processed and saved to ./clean/calendar2/Clean_singapore.csv
# Processed and saved to ./clean/calendar2/Clean_south-aegean.csv
# Processed and saved to ./clean/calendar2/Clean_stockholm.csv
# Processed and saved to ./clean/calendar2/Clean_sydney.csv
# Processed and saved to ./clean/calendar2/Clean_taipei.csv
# Processed and saved to ./clean/calendar2/Clean_tasmania.csv
# Processed and saved to ./clean/calendar2/Clean_the-hague.csv
# Processed and saved to ./clean/calendar2/Clean_thessaloniki.csv
# Processed and saved to ./clean/calendar2/Clean_tokyo.csv
# Processed and saved to ./clean/calendar2/Clean_toronto.csv
# Processed and saved to ./clean/calendar2/Clean_trentino.csv
# Processed and saved to ./clean/calendar2/Clean_twin-cities-msa.csv
# Processed and saved to ./clean/calendar2/Clean_valencia.csv
# Processed and saved to ./clean/calendar2/Clean_vancouver.csv
# Processed and saved to ./clean/calendar2/Clean_vaud.csv
# Processed and saved to ./clean/calendar2/Clean_venice.csv
# Processed and saved to ./clean/calendar2/Clean_victoria.csv
# Processed and saved to ./clean/calendar2/Clean_vienna.csv
# Processed and saved to ./clean/calendar2/Clean_washington-dc.csv
# Processed and saved to ./clean/calendar2/Clean_western-australia.csv
# Processed and saved to ./clean/calendar2/Clean_winnipeg.csv
# Processed and saved to ./clean/calendar2/Clean_zurich.csv

# %%
import pandas as pd
import os
import glob
import re

# Global dictionaries to keep track of category indices
global_category_indices = {
    'host_verifications': {},
    'host_response_time': {},
    'property_type': {},
    'room_type': {},
    'neighbourhood_cleansed': {}
}

# Function to convert percentages to decimals
def percentage_to_decimal(s):
    if isinstance(s, str) and s.endswith('%'):
        return float(s.strip('%')) / 100
    return s

# Function to convert categories to numeric indices
def category_to_index(cat, global_dict):
    if cat not in global_dict:
        global_dict[cat] = len(global_dict) + 1  # Start indexing from 1
    return global_dict[cat]

# Function to save category indices to a file
def save_category_indices(global_dict, path):
    pd.Series(global_dict).to_csv(path)

# Function to process and merge files
def process_and_merge_files(calendar_file, listings_file, output_file, 
                            last_scraped_start_date=None, last_scraped_end_date=None, 
                            mode='w', header=True, index_folder='./index_files/'):
    print(f"Processing: {calendar_file} and {listings_file}")
    
    # Read the calendar and listings data
    calendar_df = pd.read_csv(calendar_file)
    listings_df = pd.read_csv(listings_file)

    # Convert 'date' in calendar_df to datetime and ensure IDs are of the same type
    calendar_df['date'] = pd.to_datetime(calendar_df['date'], errors='coerce')
    calendar_df['listing_id'] = calendar_df['listing_id'].astype(str)
    listings_df['id'] = listings_df['id'].astype(str)
    
    # Ensure last_scraped is a datetime in listings_df for comparison
    listings_df['last_scraped'] = pd.to_datetime(listings_df['last_scraped'], errors='coerce')

    # Function to count words safely, considering non-string values
    def safe_word_count(x):
        if isinstance(x, str):
            return len(x.split())
        else:
            return 0  # Or return np.nan if you prefer
        
    listings_df['name_c'] = listings_df['name'].apply(safe_word_count)
    listings_df['description_c'] = listings_df['description'].apply(safe_word_count)
    listings_df['neighborhood_overview_c'] = listings_df['neighborhood_overview'].apply(safe_word_count)
    listings_df['host_about_c'] = listings_df['host_about'].apply(safe_word_count)
    listings_df['host_listings_count_airbnb'] = listings_df['host_listings_count']

    # Convert 't' and 'f' to 1 and 0
    for col in listings_df.columns:
        unique_values = listings_df[col].dropna().unique()
        if set(unique_values) == {'t', 'f'}:
            listings_df[col] = listings_df[col].map({'t': 1, 'f': 0})

    # Convert 'bathrooms_text' to numerical
    listings_df['bathrooms'] = listings_df['bathrooms_text'].str.extract('(\d+)').astype(float)

    # Count the number of amenities and add as a new column
    listings_df['amenities_count'] = listings_df['amenities'].str.count(',') + 1

    # Drop the original 'bathrooms_text' and 'amenities' columns
    listings_df.drop(columns=['bathrooms_text', 'amenities', 'name', 'description','neighborhood_overview', 'host_about'], inplace=True)

    # Convert specific columns to binary (0 or 1)
    listings_df['license'] = listings_df['license'].notna().astype(int)

    # Fill missing values in 'bathrooms' with 0
    listings_df['bathrooms'].fillna(0, inplace=True)

    # Convert 'host_response_rate' from percentage to decimal
    listings_df['host_response_rate'] = listings_df['host_response_rate'].apply(percentage_to_decimal)

    # Convert categorical variables to numeric indices and update global indices
    for col in ['host_verifications', 'host_response_time', 'property_type', 'room_type']:
        listings_df[col] = listings_df[col].apply(lambda x: category_to_index(x, global_category_indices[col]))

    # Convert 'neighbourhood_cleansed' to numeric index, treated separately for each city
    listings_df['neighbourhood_cleansed'] = listings_df['neighbourhood_cleansed'].apply(lambda x: category_to_index(x, global_category_indices['neighbourhood_cleansed']))

    # Keep only necessary columns from calendar and listings data
    calendar_df = calendar_df[['listing_id', 'date', 'available', 'price', 'minimum_nights', 'maximum_nights',	'price_change_count', 
                               'change_in_availability', 'month', 'quarter', 'monthly_availability_count', 'quarterly_availability_count',
                               'is_weekend', 'monthly_weekend_availability', 'price_usd']]
    listings_columns_to_keep = [
            'id',
            'last_scraped',
            'name_c', 
            'description_c', 
            'neighborhood_overview_c', 
            'host_listings_count_airbnb',             
            'host_id', 
            'host_since', 
            'host_about_c', 
            'host_response_time', 
            'host_response_rate', 
            'host_acceptance_rate', 
            'host_is_superhost', 
            'host_verifications', 
            'host_has_profile_pic', 
            'host_identity_verified', 
            'neighbourhood_cleansed', 
            'property_type', 
            'room_type', 
            'accommodates', 
            'bathrooms', 
            'bedrooms', 
            'beds', 
            'amenities_count', 
            'minimum_minimum_nights', 
            'maximum_minimum_nights', 
            'minimum_maximum_nights', 
            'maximum_maximum_nights', 
            'minimum_nights_avg_ntm', 
            'maximum_nights_avg_ntm', 
            'availability_30', 
            'availability_60', 
            'availability_90', 
            'availability_365', 
            'number_of_reviews', 
            'number_of_reviews_ltm', 
            'number_of_reviews_l30d', 
            'first_review', 
            'last_review', 
            'review_scores_rating', 
            'review_scores_accuracy', 
            'review_scores_cleanliness', 
            'review_scores_checkin', 
            'review_scores_communication', 
            'review_scores_location', 
            'review_scores_value', 
            'license', 
            'instant_bookable', 
            'calculated_host_listings_count', 
            'calculated_host_listings_count_entire_homes', 
            'calculated_host_listings_count_private_rooms', 
            'calculated_host_listings_count_shared_rooms', 
            'reviews_per_month', 
        ]

    listings_df = listings_df[listings_columns_to_keep]

    # Merge logic based on 'listing_id' from calendar_df and 'id' from listings_df
    merged_data = pd.merge(calendar_df, listings_df, left_on='listing_id', right_on='id')
    
    # Convert last_scraped_start_date and last_scraped_end_date to datetime for comparison
    if last_scraped_start_date:
        last_scraped_start_date = pd.to_datetime(last_scraped_start_date, errors='coerce')
    if last_scraped_end_date:
        last_scraped_end_date = pd.to_datetime(last_scraped_end_date, errors='coerce')

    # Filter data based on 'last_scraped' and the provided date ranges
    if last_scraped_start_date is not None and last_scraped_end_date is not None:
        merged_data = merged_data[
            (merged_data['date'] >= last_scraped_start_date) & 
            (merged_data['date'] < last_scraped_end_date)
        ]
    elif last_scraped_start_date is not None:
        # This is for the most recent file where the end date is 2023-12-31
        merged_data = merged_data[
            (merged_data['date'] >= last_scraped_start_date) & 
            (merged_data['date'] <= pd.to_datetime('2023-12-31'))
        ]

    # Save the merged data to the specified output file
    merged_data.to_csv(output_file, mode=mode, header=header, index=False)
    if mode == 'a':
        print(f"Appended data to {output_file}")
    else:
        print(f"Saved new data to {output_file}")

    # Save category indices to files
    if not os.path.exists(index_folder):
        os.makedirs(index_folder)
    for cat, idx_dict in global_category_indices.items():
        save_category_indices(idx_dict, os.path.join(index_folder, f'{cat}_index.csv'))

# Function to iterate over files and merge them for a specific city
def merge_city_data(city_name, calendar_folder, listings_folder, output_folder):
    calendar_files = sorted(glob.glob(f'{calendar_folder}/Clean_{city_name}.csv'))
    listings_files = sorted(glob.glob(os.path.join(listings_folder, f'*{city_name}*_listings.csv')), reverse=True)

    last_scraped_end_date = pd.to_datetime('2023-12-31')  # Initial end date for the most recent file
    last_scraped_start_date = None  # Initialize this variable for the first iteration

    for listings_file in listings_files:
        output_file = os.path.join(output_folder, 'merged_' + city_name + '.csv')
        
        calendar_file = calendar_files[0] if calendar_files else None
        
        if not calendar_file:
            print(f"No matching calendar file found for {listings_file}. Skipping.")
            continue

        # Update the last_scraped_start_date for the current file
        current_last_scraped = pd.read_csv(listings_file)['last_scraped'].min()
        current_last_scraped = pd.to_datetime(current_last_scraped, errors='coerce')

        # Determine whether to write a new file or append to the existing one
        if os.path.exists(output_file):
            mode = 'a'  # Append if already exists
            header = False  # Don't write the header again
        else:
            mode = 'w'  # Create a new file if not
            header = True

        # Process the files using the adjusted date ranges
        process_and_merge_files(calendar_file, listings_file, output_file, 
                                last_scraped_start_date, last_scraped_end_date, mode, header)

        # Update the last_scraped_end_date for the next iteration to be the start date of the current one
        last_scraped_start_date = current_last_scraped
        last_scraped_end_date = current_last_scraped - pd.Timedelta(days=1)  # Set end date to the day before the current last_scraped

# Function to extract city names from the listings files
def get_city_names_from_files(listings_folder):
    city_names = set()
    files = glob.glob(f'{listings_folder}/*_listings.csv')
    for file in files:
        match = re.search(r'\d{4}_\d{2}_(.*?)_.*_.*_listings\.csv', os.path.basename(file))
        if match:
            city_names.add(match.group(1))
    return city_names

# Main script to iterate over all cities and merge data
def merge_all_cities():
    calendar_folder = './clean/calendar2'
    listings_folder = './all/listings'
    output_folder = './merge/'

    # Extract city names from the listings files
    city_names = get_city_names_from_files(listings_folder)

    # Process each city
    for city_name in city_names:
        print(f"Starting merge process for {city_name}")
        merge_city_data(city_name, calendar_folder, listings_folder, output_folder)

# Start the process for all cities
merge_all_cities()
# Out:
# Starting merge process for portland
# Processing: ./clean/calendar2/Clean_portland.csv and ./all/listings\2023_09_portland_or_united-states_listings.csv
# Saved new data to ./merge/merged_portland.csv
# Processing: ./clean/calendar2/Clean_portland.csv and ./all/listings\2023_06_portland_or_united-states_listings.csv
# Appended data to ./merge/merged_portland.csv
# Processing: ./clean/calendar2/Clean_portland.csv and ./all/listings\2023_03_portland_or_united-states_listings.csv
# Appended data to ./merge/merged_portland.csv
# Processing: ./clean/calendar2/Clean_portland.csv and ./all/listings\2022_12_portland_or_united-states_listings.csv
# Appended data to ./merge/merged_portland.csv
# Processing: ./clean/calendar2/Clean_portland.csv and ./all/listings\2022_09_portland_or_united-states_listings.csv
# Appended data to ./merge/merged_portland.csv
# Starting merge process for madrid
# Processing: ./clean/calendar2/Clean_madrid.csv and ./all/listings\2023_09_madrid_comunidad de madrid_spain_listings.csv
# Saved new data to ./merge/merged_madrid.csv
# Processing: ./clean/calendar2/Clean_madrid.csv and ./all/listings\2023_06_madrid_comunidad de madrid_spain_listings.csv
# Appended data to ./merge/merged_madrid.csv
# Processing: ./clean/calendar2/Clean_madrid.csv and ./all/listings\2023_03_madrid_comunidad de madrid_spain_listings.csv
# Appended data to ./merge/merged_madrid.csv
# Processing: ./clean/calendar2/Clean_madrid.csv and ./all/listings\2022_12_madrid_comunidad de madrid_spain_listings.csv
# Appended data to ./merge/merged_madrid.csv
# Processing: ./clean/calendar2/Clean_madrid.csv and ./all/listings\2022_09_madrid_comunidad de madrid_spain_listings.csv
# Appended data to ./merge/merged_madrid.csv
# Starting merge process for chicago
# Processing: ./clean/calendar2/Clean_chicago.csv and ./all/listings\2023_09_chicago_il_united-states_listings.csv
# Saved new data to ./merge/merged_chicago.csv
# Processing: ./clean/calendar2/Clean_chicago.csv and ./all/listings\2023_06_chicago_il_united-states_listings.csv
# Appended data to ./merge/merged_chicago.csv
# Processing: ./clean/calendar2/Clean_chicago.csv and ./all/listings\2023_03_chicago_il_united-states_listings.csv
# Appended data to ./merge/merged_chicago.csv
# Processing: ./clean/calendar2/Clean_chicago.csv and ./all/listings\2022_12_chicago_il_united-states_listings.csv
# Appended data to ./merge/merged_chicago.csv
# Processing: ./clean/calendar2/Clean_chicago.csv and ./all/listings\2022_09_chicago_il_united-states_listings.csv
# Appended data to ./merge/merged_chicago.csv
# Starting merge process for washington-dc
# Processing: ./clean/calendar2/Clean_washington-dc.csv and ./all/listings\2023_09_washington-dc_dc_united-states_listings.csv
# Saved new data to ./merge/merged_washington-dc.csv
# Processing: ./clean/calendar2/Clean_washington-dc.csv and ./all/listings\2023_06_washington-dc_dc_united-states_listings.csv
# Appended data to ./merge/merged_washington-dc.csv
# Processing: ./clean/calendar2/Clean_washington-dc.csv and ./all/listings\2023_03_washington-dc_dc_united-states_listings.csv
# Appended data to ./merge/merged_washington-dc.csv
# Processing: ./clean/calendar2/Clean_washington-dc.csv and ./all/listings\2022_12_washington-dc_dc_united-states_listings.csv
# Appended data to ./merge/merged_washington-dc.csv
# Processing: ./clean/calendar2/Clean_washington-dc.csv and ./all/listings\2022_09_washington-dc_dc_united-states_listings.csv
# Appended data to ./merge/merged_washington-dc.csv
# Starting merge process for twin-cities-msa
# Processing: ./clean/calendar2/Clean_twin-cities-msa.csv and ./all/listings\2023_09_twin-cities-msa_mn_united-states_listings.csv
# Saved new data to ./merge/merged_twin-cities-msa.csv
# Processing: ./clean/calendar2/Clean_twin-cities-msa.csv and ./all/listings\2023_06_twin-cities-msa_mn_united-states_listings.csv
# Appended data to ./merge/merged_twin-cities-msa.csv
# Processing: ./clean/calendar2/Clean_twin-cities-msa.csv and ./all/listings\2023_03_twin-cities-msa_mn_united-states_listings.csv
# Appended data to ./merge/merged_twin-cities-msa.csv
# Processing: ./clean/calendar2/Clean_twin-cities-msa.csv and ./all/listings\2022_12_twin-cities-msa_mn_united-states_listings.csv
# Appended data to ./merge/merged_twin-cities-msa.csv
# Processing: ./clean/calendar2/Clean_twin-cities-msa.csv and ./all/listings\2022_09_twin-cities-msa_mn_united-states_listings.csv
# Appended data to ./merge/merged_twin-cities-msa.csv
# Starting merge process for prague
# Processing: ./clean/calendar2/Clean_prague.csv and ./all/listings\2023_09_prague_prague_czech-republic_listings.csv
# Saved new data to ./merge/merged_prague.csv
# Processing: ./clean/calendar2/Clean_prague.csv and ./all/listings\2023_06_prague_prague_czech-republic_listings.csv
# Appended data to ./merge/merged_prague.csv
# Processing: ./clean/calendar2/Clean_prague.csv and ./all/listings\2023_03_prague_prague_czech-republic_listings.csv
# Appended data to ./merge/merged_prague.csv
# Processing: ./clean/calendar2/Clean_prague.csv and ./all/listings\2022_12_prague_prague_czech-republic_listings.csv
# Appended data to ./merge/merged_prague.csv
# Processing: ./clean/calendar2/Clean_prague.csv and ./all/listings\2022_09_prague_prague_czech-republic_listings.csv
# Appended data to ./merge/merged_prague.csv
# Starting merge process for mornington-peninsula
# Processing: ./clean/calendar2/Clean_mornington-peninsula.csv and ./all/listings\2023_09_mornington-peninsula_vic_australia_listings.csv
# Saved new data to ./merge/merged_mornington-peninsula.csv
# Processing: ./clean/calendar2/Clean_mornington-peninsula.csv and ./all/listings\2023_06_mornington-peninsula_vic_australia_listings.csv
# Appended data to ./merge/merged_mornington-peninsula.csv
# Processing: ./clean/calendar2/Clean_mornington-peninsula.csv and ./all/listings\2023_03_mornington-peninsula_vic_australia_listings.csv
# Appended data to ./merge/merged_mornington-peninsula.csv
# Processing: ./clean/calendar2/Clean_mornington-peninsula.csv and ./all/listings\2022_12_mornington-peninsula_vic_australia_listings.csv
# Appended data to ./merge/merged_mornington-peninsula.csv
# Processing: ./clean/calendar2/Clean_mornington-peninsula.csv and ./all/listings\2022_09_mornington-peninsula_vic_australia_listings.csv
# Appended data to ./merge/merged_mornington-peninsula.csv
# Processing: ./clean/calendar2/Clean_mornington-peninsula.csv and ./all/listings\2022_06_mornington-peninsula_vic_australia_listings.csv
# Appended data to ./merge/merged_mornington-peninsula.csv
# Starting merge process for vienna
# Processing: ./clean/calendar2/Clean_vienna.csv and ./all/listings\2023_09_vienna_vienna_austria_listings.csv
# Saved new data to ./merge/merged_vienna.csv
# Processing: ./clean/calendar2/Clean_vienna.csv and ./all/listings\2023_06_vienna_vienna_austria_listings.csv
# Appended data to ./merge/merged_vienna.csv
# Processing: ./clean/calendar2/Clean_vienna.csv and ./all/listings\2023_03_vienna_vienna_austria_listings.csv
# Appended data to ./merge/merged_vienna.csv
# Processing: ./clean/calendar2/Clean_vienna.csv and ./all/listings\2022_12_vienna_vienna_austria_listings.csv
# Appended data to ./merge/merged_vienna.csv
# Processing: ./clean/calendar2/Clean_vienna.csv and ./all/listings\2022_09_vienna_vienna_austria_listings.csv
# Appended data to ./merge/merged_vienna.csv
# Starting merge process for menorca
# Processing: ./clean/calendar2/Clean_menorca.csv and ./all/listings\2023_09_menorca_islas baleares_spain_listings.csv
# Saved new data to ./merge/merged_menorca.csv
# Processing: ./clean/calendar2/Clean_menorca.csv and ./all/listings\2023_06_menorca_islas baleares_spain_listings.csv
# Appended data to ./merge/merged_menorca.csv
# Processing: ./clean/calendar2/Clean_menorca.csv and ./all/listings\2023_03_menorca_islas baleares_spain_listings.csv
# Appended data to ./merge/merged_menorca.csv
# Processing: ./clean/calendar2/Clean_menorca.csv and ./all/listings\2022_12_menorca_islas baleares_spain_listings.csv
# Appended data to ./merge/merged_menorca.csv
# Processing: ./clean/calendar2/Clean_menorca.csv and ./all/listings\2022_09_menorca_islas baleares_spain_listings.csv
# Appended data to ./merge/merged_menorca.csv
# Starting merge process for rochester
# Processing: ./clean/calendar2/Clean_rochester.csv and ./all/listings\2023_10_rochester_ny_united-states_listings.csv
# Saved new data to ./merge/merged_rochester.csv
# Starting merge process for columbus
# Processing: ./clean/calendar2/Clean_columbus.csv and ./all/listings\2023_09_columbus_oh_united-states_listings.csv
# Saved new data to ./merge/merged_columbus.csv
# Processing: ./clean/calendar2/Clean_columbus.csv and ./all/listings\2023_06_columbus_oh_united-states_listings.csv
# Appended data to ./merge/merged_columbus.csv
# Processing: ./clean/calendar2/Clean_columbus.csv and ./all/listings\2023_03_columbus_oh_united-states_listings.csv
# Appended data to ./merge/merged_columbus.csv
# Processing: ./clean/calendar2/Clean_columbus.csv and ./all/listings\2022_12_columbus_oh_united-states_listings.csv
# Appended data to ./merge/merged_columbus.csv
# Processing: ./clean/calendar2/Clean_columbus.csv and ./all/listings\2022_09_columbus_oh_united-states_listings.csv
# Appended data to ./merge/merged_columbus.csv
# Starting merge process for austin
# Processing: ./clean/calendar2/Clean_austin.csv and ./all/listings\2023_09_austin_tx_united-states_listings.csv
# Saved new data to ./merge/merged_austin.csv
# Processing: ./clean/calendar2/Clean_austin.csv and ./all/listings\2023_06_austin_tx_united-states_listings.csv
# Appended data to ./merge/merged_austin.csv
# Processing: ./clean/calendar2/Clean_austin.csv and ./all/listings\2023_03_austin_tx_united-states_listings.csv
# Appended data to ./merge/merged_austin.csv
# Processing: ./clean/calendar2/Clean_austin.csv and ./all/listings\2022_12_austin_tx_united-states_listings.csv
# Appended data to ./merge/merged_austin.csv
# Processing: ./clean/calendar2/Clean_austin.csv and ./all/listings\2022_09_austin_tx_united-states_listings.csv
# Appended data to ./merge/merged_austin.csv
# Starting merge process for santa-clara-county
# Processing: ./clean/calendar2/Clean_santa-clara-county.csv and ./all/listings\2023_09_santa-clara-county_ca_united-states_listings.csv
# Saved new data to ./merge/merged_santa-clara-county.csv
# Processing: ./clean/calendar2/Clean_santa-clara-county.csv and ./all/listings\2023_06_santa-clara-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-clara-county.csv
# Processing: ./clean/calendar2/Clean_santa-clara-county.csv and ./all/listings\2023_03_santa-clara-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-clara-county.csv
# Processing: ./clean/calendar2/Clean_santa-clara-county.csv and ./all/listings\2022_12_santa-clara-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-clara-county.csv
# Processing: ./clean/calendar2/Clean_santa-clara-county.csv and ./all/listings\2022_09_santa-clara-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-clara-county.csv
# Starting merge process for vaud
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_11_vaud_vd_switzerland_listings.csv
# Saved new data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_10_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_09_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_08_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_07_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_06_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_05_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_04_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_03_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_02_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2023_01_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_12_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_11_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_10_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_09_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_08_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_07_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_06_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_05_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_04_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_03_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_02_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2022_01_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2021_12_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2021_11_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2021_10_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2021_09_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Processing: ./clean/calendar2/Clean_vaud.csv and ./all/listings\2021_06_vaud_vd_switzerland_listings.csv
# Appended data to ./merge/merged_vaud.csv
# Starting merge process for thessaloniki
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2023_09_thessaloniki_central macedonia_greece_listings.csv
# Saved new data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2023_06_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2023_03_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2022_12_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2022_09_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2022_06_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2022_03_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2021_12_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2021_09_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Processing: ./clean/calendar2/Clean_thessaloniki.csv and ./all/listings\2021_06_thessaloniki_central macedonia_greece_listings.csv
# Appended data to ./merge/merged_thessaloniki.csv
# Starting merge process for barcelona
# Processing: ./clean/calendar2/Clean_barcelona.csv and ./all/listings\2023_09_barcelona_catalonia_spain_listings.csv
# Saved new data to ./merge/merged_barcelona.csv
# Processing: ./clean/calendar2/Clean_barcelona.csv and ./all/listings\2023_06_barcelona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_barcelona.csv
# Processing: ./clean/calendar2/Clean_barcelona.csv and ./all/listings\2023_03_barcelona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_barcelona.csv
# Processing: ./clean/calendar2/Clean_barcelona.csv and ./all/listings\2022_12_barcelona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_barcelona.csv
# Processing: ./clean/calendar2/Clean_barcelona.csv and ./all/listings\2022_09_barcelona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_barcelona.csv
# Starting merge process for euskadi
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2023_09_euskadi_pv_spain_listings.csv
# Saved new data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2023_06_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2023_03_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2022_12_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2022_09_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2022_06_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2022_03_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2021_12_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2021_09_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Processing: ./clean/calendar2/Clean_euskadi.csv and ./all/listings\2021_06_euskadi_pv_spain_listings.csv
# Appended data to ./merge/merged_euskadi.csv
# Starting merge process for san-diego
# Processing: ./clean/calendar2/Clean_san-diego.csv and ./all/listings\2023_09_san-diego_ca_united-states_listings.csv
# Saved new data to ./merge/merged_san-diego.csv
# Processing: ./clean/calendar2/Clean_san-diego.csv and ./all/listings\2023_06_san-diego_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-diego.csv
# Processing: ./clean/calendar2/Clean_san-diego.csv and ./all/listings\2023_03_san-diego_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-diego.csv
# Processing: ./clean/calendar2/Clean_san-diego.csv and ./all/listings\2022_12_san-diego_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-diego.csv
# Processing: ./clean/calendar2/Clean_san-diego.csv and ./all/listings\2022_09_san-diego_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-diego.csv
# Starting merge process for denver
# Processing: ./clean/calendar2/Clean_denver.csv and ./all/listings\2023_09_denver_co_united-states_listings.csv
# Saved new data to ./merge/merged_denver.csv
# Processing: ./clean/calendar2/Clean_denver.csv and ./all/listings\2023_06_denver_co_united-states_listings.csv
# Appended data to ./merge/merged_denver.csv
# Processing: ./clean/calendar2/Clean_denver.csv and ./all/listings\2023_03_denver_co_united-states_listings.csv
# Appended data to ./merge/merged_denver.csv
# Processing: ./clean/calendar2/Clean_denver.csv and ./all/listings\2022_12_denver_co_united-states_listings.csv
# Appended data to ./merge/merged_denver.csv
# Processing: ./clean/calendar2/Clean_denver.csv and ./all/listings\2022_09_denver_co_united-states_listings.csv
# Appended data to ./merge/merged_denver.csv
# Starting merge process for seattle
# Processing: ./clean/calendar2/Clean_seattle.csv and ./all/listings\2023_09_seattle_wa_united-states_listings.csv
# Saved new data to ./merge/merged_seattle.csv
# Processing: ./clean/calendar2/Clean_seattle.csv and ./all/listings\2023_06_seattle_wa_united-states_listings.csv
# Appended data to ./merge/merged_seattle.csv
# Processing: ./clean/calendar2/Clean_seattle.csv and ./all/listings\2023_03_seattle_wa_united-states_listings.csv
# Appended data to ./merge/merged_seattle.csv
# Processing: ./clean/calendar2/Clean_seattle.csv and ./all/listings\2022_12_seattle_wa_united-states_listings.csv
# Appended data to ./merge/merged_seattle.csv
# Processing: ./clean/calendar2/Clean_seattle.csv and ./all/listings\2022_09_seattle_wa_united-states_listings.csv
# Appended data to ./merge/merged_seattle.csv
# Starting merge process for asheville
# Processing: ./clean/calendar2/Clean_asheville.csv and ./all/listings\2023_09_asheville_nc_united-states_listings.csv
# Saved new data to ./merge/merged_asheville.csv
# Processing: ./clean/calendar2/Clean_asheville.csv and ./all/listings\2023_06_asheville_nc_united-states_listings.csv
# Appended data to ./merge/merged_asheville.csv
# Processing: ./clean/calendar2/Clean_asheville.csv and ./all/listings\2023_03_asheville_nc_united-states_listings.csv
# Appended data to ./merge/merged_asheville.csv
# Processing: ./clean/calendar2/Clean_asheville.csv and ./all/listings\2022_12_asheville_nc_united-states_listings.csv
# Appended data to ./merge/merged_asheville.csv
# Processing: ./clean/calendar2/Clean_asheville.csv and ./all/listings\2022_09_asheville_nc_united-states_listings.csv
# Appended data to ./merge/merged_asheville.csv
# Starting merge process for athens
# Processing: ./clean/calendar2/Clean_athens.csv and ./all/listings\2023_09_athens_attica_greece_listings.csv
# Saved new data to ./merge/merged_athens.csv
# Processing: ./clean/calendar2/Clean_athens.csv and ./all/listings\2023_06_athens_attica_greece_listings.csv
# Appended data to ./merge/merged_athens.csv
# Processing: ./clean/calendar2/Clean_athens.csv and ./all/listings\2023_03_athens_attica_greece_listings.csv
# Appended data to ./merge/merged_athens.csv
# Processing: ./clean/calendar2/Clean_athens.csv and ./all/listings\2022_12_athens_attica_greece_listings.csv
# Appended data to ./merge/merged_athens.csv
# Processing: ./clean/calendar2/Clean_athens.csv and ./all/listings\2022_09_athens_attica_greece_listings.csv
# Appended data to ./merge/merged_athens.csv
# Starting merge process for santa-cruz-county
# Processing: ./clean/calendar2/Clean_santa-cruz-county.csv and ./all/listings\2023_09_santa-cruz-county_ca_united-states_listings.csv
# Saved new data to ./merge/merged_santa-cruz-county.csv
# Processing: ./clean/calendar2/Clean_santa-cruz-county.csv and ./all/listings\2023_06_santa-cruz-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-cruz-county.csv
# Processing: ./clean/calendar2/Clean_santa-cruz-county.csv and ./all/listings\2023_03_santa-cruz-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-cruz-county.csv
# Processing: ./clean/calendar2/Clean_santa-cruz-county.csv and ./all/listings\2022_12_santa-cruz-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-cruz-county.csv
# Processing: ./clean/calendar2/Clean_santa-cruz-county.csv and ./all/listings\2022_09_santa-cruz-county_ca_united-states_listings.csv
# Appended data to ./merge/merged_santa-cruz-county.csv
# Starting merge process for dublin
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2023_09_dublin_leinster_ireland_listings.csv
# Saved new data to ./merge/merged_dublin.csv
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2023_06_dublin_leinster_ireland_listings.csv
# Appended data to ./merge/merged_dublin.csv
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2023_03_dublin_leinster_ireland_listings.csv
# Appended data to ./merge/merged_dublin.csv
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2022_12_dublin_leinster_ireland_listings.csv
# Appended data to ./merge/merged_dublin.csv
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2022_09_dublin_leinster_ireland_listings.csv
# Appended data to ./merge/merged_dublin.csv
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2022_06_dublin_leinster_ireland_listings.csv
# Appended data to ./merge/merged_dublin.csv
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2022_03_dublin_leinster_ireland_listings.csv
# Appended data to ./merge/merged_dublin.csv
# Processing: ./clean/calendar2/Clean_dublin.csv and ./all/listings\2021_12_dublin_leinster_ireland_listings.csv
# Appended data to ./merge/merged_dublin.csv
# Starting merge process for copenhagen
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2023_09_copenhagen_hovedstaden_denmark_listings.csv
# Saved new data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2023_06_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2023_03_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2022_12_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2022_09_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2022_06_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2022_03_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2021_12_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2021_09_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Processing: ./clean/calendar2/Clean_copenhagen.csv and ./all/listings\2021_06_copenhagen_hovedstaden_denmark_listings.csv
# Appended data to ./merge/merged_copenhagen.csv
# Starting merge process for san-francisco
# Processing: ./clean/calendar2/Clean_san-francisco.csv and ./all/listings\2023_09_san-francisco_ca_united-states_listings.csv
# Saved new data to ./merge/merged_san-francisco.csv
# Processing: ./clean/calendar2/Clean_san-francisco.csv and ./all/listings\2023_06_san-francisco_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-francisco.csv
# Processing: ./clean/calendar2/Clean_san-francisco.csv and ./all/listings\2023_03_san-francisco_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-francisco.csv
# Processing: ./clean/calendar2/Clean_san-francisco.csv and ./all/listings\2022_12_san-francisco_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-francisco.csv
# Processing: ./clean/calendar2/Clean_san-francisco.csv and ./all/listings\2022_09_san-francisco_ca_united-states_listings.csv
# Appended data to ./merge/merged_san-francisco.csv
# Starting merge process for albany
# Processing: ./clean/calendar2/Clean_albany.csv and ./all/listings\2023_10_albany_ny_united-states_listings.csv
# Saved new data to ./merge/merged_albany.csv
# Processing: ./clean/calendar2/Clean_albany.csv and ./all/listings\2023_09_albany_ny_united-states_listings.csv
# Appended data to ./merge/merged_albany.csv
# Processing: ./clean/calendar2/Clean_albany.csv and ./all/listings\2023_08_albany_ny_united-states_listings.csv
# Appended data to ./merge/merged_albany.csv
# Processing: ./clean/calendar2/Clean_albany.csv and ./all/listings\2023_07_albany_ny_united-states_listings.csv
# Appended data to ./merge/merged_albany.csv
# Processing: ./clean/calendar2/Clean_albany.csv and ./all/listings\2023_06_albany_ny_united-states_listings.csv
# Appended data to ./merge/merged_albany.csv
# Processing: ./clean/calendar2/Clean_albany.csv and ./all/listings\2023_05_albany_ny_united-states_listings.csv
# Appended data to ./merge/merged_albany.csv
# Processing: ./clean/calendar2/Clean_albany.csv and ./all/listings\2023_04_albany_ny_united-states_listings.csv
# Appended data to ./merge/merged_albany.csv
# Starting merge process for paris
# Processing: ./clean/calendar2/Clean_paris.csv and ./all/listings\2023_09_paris_ile de france_france_listings.csv
# Saved new data to ./merge/merged_paris.csv
# Processing: ./clean/calendar2/Clean_paris.csv and ./all/listings\2023_06_paris_ile de france_france_listings.csv
# Appended data to ./merge/merged_paris.csv
# Processing: ./clean/calendar2/Clean_paris.csv and ./all/listings\2023_03_paris_ile de france_france_listings.csv
# Appended data to ./merge/merged_paris.csv
# Starting merge process for northern-rivers
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2023_09_northern-rivers_nsw_australia_listings.csv
# Saved new data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2023_06_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2023_03_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2022_12_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2022_09_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2022_06_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2022_03_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2021_12_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2021_09_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Processing: ./clean/calendar2/Clean_northern-rivers.csv and ./all/listings\2021_06_northern-rivers_nsw_australia_listings.csv
# Appended data to ./merge/merged_northern-rivers.csv
# Starting merge process for new-york-city
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_11_new-york-city_ny_united-states_listings.csv
# Saved new data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_10_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_09_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_08_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_07_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_06_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# C:\Users\yirsu\AppData\Local\Temp\ipykernel_29184\2867873049.py:255: DtypeWarning: Columns (68) have mixed types.Specify dtype option on import or set low_memory=False.
#   merge_city_data(city_name, calendar_folder, listings_folder, output_folder)
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_05_new-york-city_ny_united-states_listings.csv
# C:\Users\yirsu\AppData\Local\Temp\ipykernel_29184\2867873049.py:220: DtypeWarning: Columns (68) have mixed types.Specify dtype option on import or set low_memory=False.
#   process_and_merge_files(calendar_file, listings_file, output_file,
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_04_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_03_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_02_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2023_01_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2022_12_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Processing: ./clean/calendar2/Clean_new-york-city.csv and ./all/listings\2022_09_new-york-city_ny_united-states_listings.csv
# Appended data to ./merge/merged_new-york-city.csv
# Starting merge process for hong-kong
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2023_09_hong-kong_hk_china_listings.csv
# Saved new data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2023_06_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2023_03_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2022_12_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2022_09_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2022_06_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2022_03_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2021_12_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Processing: ./clean/calendar2/Clean_hong-kong.csv and ./all/listings\2021_09_hong-kong_hk_china_listings.csv
# Appended data to ./merge/merged_hong-kong.csv
# Starting merge process for antwerp
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2023_09_antwerp_vlg_belgium_listings.csv
# Saved new data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2023_06_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2023_03_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2022_12_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2022_09_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2022_06_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2022_03_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2021_12_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2021_09_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Processing: ./clean/calendar2/Clean_antwerp.csv and ./all/listings\2021_06_antwerp_vlg_belgium_listings.csv
# Appended data to ./merge/merged_antwerp.csv
# Starting merge process for bergamo
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2023_09_bergamo_lombardia_italy_listings.csv
# Saved new data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2023_06_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2023_03_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2022_12_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2022_09_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2022_06_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2022_03_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2021_12_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2021_09_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Processing: ./clean/calendar2/Clean_bergamo.csv and ./all/listings\2021_06_bergamo_lombardia_italy_listings.csv
# Appended data to ./merge/merged_bergamo.csv
# Starting merge process for ghent
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2023_09_ghent_vlg_belgium_listings.csv
# Saved new data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2023_06_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2023_03_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2022_12_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2022_09_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2022_06_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2022_03_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2021_12_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2021_09_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Processing: ./clean/calendar2/Clean_ghent.csv and ./all/listings\2021_06_ghent_vlg_belgium_listings.csv
# Appended data to ./merge/merged_ghent.csv
# Starting merge process for barwon-south-west-vic
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2023_09_barwon-south-west-vic_vic_australia_listings.csv
# Saved new data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2023_06_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2023_03_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2022_12_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2022_09_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2022_06_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2022_03_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2021_12_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2021_09_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Processing: ./clean/calendar2/Clean_barwon-south-west-vic.csv and ./all/listings\2021_06_barwon-south-west-vic_vic_australia_listings.csv
# Appended data to ./merge/merged_barwon-south-west-vic.csv
# Starting merge process for lisbon
# Processing: ./clean/calendar2/Clean_lisbon.csv and ./all/listings\2023_09_lisbon_lisbon_portugal_listings.csv
# Saved new data to ./merge/merged_lisbon.csv
# Processing: ./clean/calendar2/Clean_lisbon.csv and ./all/listings\2023_06_lisbon_lisbon_portugal_listings.csv
# Appended data to ./merge/merged_lisbon.csv
# Processing: ./clean/calendar2/Clean_lisbon.csv and ./all/listings\2023_03_lisbon_lisbon_portugal_listings.csv
# Appended data to ./merge/merged_lisbon.csv
# Processing: ./clean/calendar2/Clean_lisbon.csv and ./all/listings\2022_12_lisbon_lisbon_portugal_listings.csv
# Appended data to ./merge/merged_lisbon.csv
# Processing: ./clean/calendar2/Clean_lisbon.csv and ./all/listings\2022_09_lisbon_lisbon_portugal_listings.csv
# Appended data to ./merge/merged_lisbon.csv
# Starting merge process for rhode-island
# Processing: ./clean/calendar2/Clean_rhode-island.csv and ./all/listings\2023_09_rhode-island_ri_united-states_listings.csv
# Saved new data to ./merge/merged_rhode-island.csv
# Processing: ./clean/calendar2/Clean_rhode-island.csv and ./all/listings\2023_06_rhode-island_ri_united-states_listings.csv
# Appended data to ./merge/merged_rhode-island.csv
# Processing: ./clean/calendar2/Clean_rhode-island.csv and ./all/listings\2023_03_rhode-island_ri_united-states_listings.csv
# Appended data to ./merge/merged_rhode-island.csv
# Processing: ./clean/calendar2/Clean_rhode-island.csv and ./all/listings\2022_12_rhode-island_ri_united-states_listings.csv
# Appended data to ./merge/merged_rhode-island.csv
# Processing: ./clean/calendar2/Clean_rhode-island.csv and ./all/listings\2022_09_rhode-island_ri_united-states_listings.csv
# Appended data to ./merge/merged_rhode-island.csv
# Starting merge process for mexico-city
# Processing: ./clean/calendar2/Clean_mexico-city.csv and ./all/listings\2023_09_mexico-city_df_mexico_listings.csv
# Saved new data to ./merge/merged_mexico-city.csv
# Processing: ./clean/calendar2/Clean_mexico-city.csv and ./all/listings\2023_06_mexico-city_df_mexico_listings.csv
# Appended data to ./merge/merged_mexico-city.csv
# Processing: ./clean/calendar2/Clean_mexico-city.csv and ./all/listings\2023_03_mexico-city_df_mexico_listings.csv
# Appended data to ./merge/merged_mexico-city.csv
# Processing: ./clean/calendar2/Clean_mexico-city.csv and ./all/listings\2022_12_mexico-city_df_mexico_listings.csv
# Appended data to ./merge/merged_mexico-city.csv
# Starting merge process for nashville
# Processing: ./clean/calendar2/Clean_nashville.csv and ./all/listings\2023_09_nashville_tn_united-states_listings.csv
# Saved new data to ./merge/merged_nashville.csv
# Processing: ./clean/calendar2/Clean_nashville.csv and ./all/listings\2023_06_nashville_tn_united-states_listings.csv
# Appended data to ./merge/merged_nashville.csv
# Processing: ./clean/calendar2/Clean_nashville.csv and ./all/listings\2023_03_nashville_tn_united-states_listings.csv
# Appended data to ./merge/merged_nashville.csv
# Processing: ./clean/calendar2/Clean_nashville.csv and ./all/listings\2022_12_nashville_tn_united-states_listings.csv
# Appended data to ./merge/merged_nashville.csv
# Processing: ./clean/calendar2/Clean_nashville.csv and ./all/listings\2022_09_nashville_tn_united-states_listings.csv
# Appended data to ./merge/merged_nashville.csv
# Starting merge process for toronto
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_11_toronto_on_canada_listings.csv
# Saved new data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_10_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_09_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_08_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_07_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_06_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_05_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_04_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_03_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_02_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2023_01_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2022_12_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Processing: ./clean/calendar2/Clean_toronto.csv and ./all/listings\2022_09_toronto_on_canada_listings.csv
# Appended data to ./merge/merged_toronto.csv
# Starting merge process for santiago
# Processing: ./clean/calendar2/Clean_santiago.csv and ./all/listings\2023_09_santiago_rm_chile_listings.csv
# Saved new data to ./merge/merged_santiago.csv
# ...
# Processing: ./clean/calendar2/Clean_berlin.csv and ./all/listings\2023_03_berlin_be_germany_listings.csv
# Appended data to ./merge/merged_berlin.csv
# Processing: ./clean/calendar2/Clean_berlin.csv and ./all/listings\2022_12_berlin_be_germany_listings.csv
# Appended data to ./merge/merged_berlin.csv
# Starting merge process for new-orleans
# Processing: ./clean/calendar2/Clean_new-orleans.csv and ./all/listings\2023_09_new-orleans_la_united-states_listings.csv
# Saved new data to ./merge/merged_new-orleans.csv
# Processing: ./clean/calendar2/Clean_new-orleans.csv and ./all/listings\2023_06_new-orleans_la_united-states_listings.csv
# Appended data to ./merge/merged_new-orleans.csv
# Processing: ./clean/calendar2/Clean_new-orleans.csv and ./all/listings\2023_03_new-orleans_la_united-states_listings.csv
# Appended data to ./merge/merged_new-orleans.csv
# Processing: ./clean/calendar2/Clean_new-orleans.csv and ./all/listings\2022_12_new-orleans_la_united-states_listings.csv
# Appended data to ./merge/merged_new-orleans.csv
# Processing: ./clean/calendar2/Clean_new-orleans.csv and ./all/listings\2022_09_new-orleans_la_united-states_listings.csv
# Appended data to ./merge/merged_new-orleans.csv
# Starting merge process for riga
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2023_09_riga_riga_latvia_listings.csv
# Saved new data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2023_06_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2023_03_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2022_12_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2022_09_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2022_06_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2022_03_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2021_12_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2021_09_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Processing: ./clean/calendar2/Clean_riga.csv and ./all/listings\2021_06_riga_riga_latvia_listings.csv
# Appended data to ./merge/merged_riga.csv
# Starting merge process for melbourne
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2023_09_melbourne_vic_australia_listings.csv
# Saved new data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2023_06_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2023_03_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2022_12_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2022_09_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2022_06_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2022_03_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2021_12_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2021_09_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Processing: ./clean/calendar2/Clean_melbourne.csv and ./all/listings\2021_06_melbourne_vic_australia_listings.csv
# Appended data to ./merge/merged_melbourne.csv
# Starting merge process for broward-county
# Processing: ./clean/calendar2/Clean_broward-county.csv and ./all/listings\2023_09_broward-county_fl_united-states_listings.csv
# Saved new data to ./merge/merged_broward-county.csv
# Processing: ./clean/calendar2/Clean_broward-county.csv and ./all/listings\2023_06_broward-county_fl_united-states_listings.csv
# Appended data to ./merge/merged_broward-county.csv
# Processing: ./clean/calendar2/Clean_broward-county.csv and ./all/listings\2023_03_broward-county_fl_united-states_listings.csv
# Appended data to ./merge/merged_broward-county.csv
# Processing: ./clean/calendar2/Clean_broward-county.csv and ./all/listings\2022_12_broward-county_fl_united-states_listings.csv
# Appended data to ./merge/merged_broward-county.csv
# Processing: ./clean/calendar2/Clean_broward-county.csv and ./all/listings\2022_09_broward-county_fl_united-states_listings.csv
# Appended data to ./merge/merged_broward-county.csv
# Starting merge process for tasmania
# Processing: ./clean/calendar2/Clean_tasmania.csv and ./all/listings\2023_09_tasmania_tas_australia_listings.csv
# Saved new data to ./merge/merged_tasmania.csv
# Processing: ./clean/calendar2/Clean_tasmania.csv and ./all/listings\2023_06_tasmania_tas_australia_listings.csv
# Appended data to ./merge/merged_tasmania.csv
# Processing: ./clean/calendar2/Clean_tasmania.csv and ./all/listings\2023_03_tasmania_tas_australia_listings.csv
# Appended data to ./merge/merged_tasmania.csv
# Processing: ./clean/calendar2/Clean_tasmania.csv and ./all/listings\2022_12_tasmania_tas_australia_listings.csv
# Appended data to ./merge/merged_tasmania.csv
# Starting merge process for puglia
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2023_09_puglia_puglia_italy_listings.csv
# Saved new data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2023_06_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2023_03_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2022_12_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2022_09_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2022_06_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2022_03_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2021_12_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Processing: ./clean/calendar2/Clean_puglia.csv and ./all/listings\2021_09_puglia_puglia_italy_listings.csv
# Appended data to ./merge/merged_puglia.csv
# Starting merge process for the-hague
# Processing: ./clean/calendar2/Clean_the-hague.csv and ./all/listings\2023_09_the-hague_south holland_the-netherlands_listings.csv
# Saved new data to ./merge/merged_the-hague.csv
# Processing: ./clean/calendar2/Clean_the-hague.csv and ./all/listings\2023_06_the-hague_south holland_the-netherlands_listings.csv
# Appended data to ./merge/merged_the-hague.csv
# Processing: ./clean/calendar2/Clean_the-hague.csv and ./all/listings\2023_03_the-hague_south holland_the-netherlands_listings.csv
# Appended data to ./merge/merged_the-hague.csv
# Processing: ./clean/calendar2/Clean_the-hague.csv and ./all/listings\2022_12_the-hague_south holland_the-netherlands_listings.csv
# Appended data to ./merge/merged_the-hague.csv
# Processing: ./clean/calendar2/Clean_the-hague.csv and ./all/listings\2022_09_the-hague_south holland_the-netherlands_listings.csv
# Appended data to ./merge/merged_the-hague.csv
# Processing: ./clean/calendar2/Clean_the-hague.csv and ./all/listings\2022_06_the-hague_south holland_the-netherlands_listings.csv
# Appended data to ./merge/merged_the-hague.csv
# Processing: ./clean/calendar2/Clean_the-hague.csv and ./all/listings\2022_03_the-hague_south holland_the-netherlands_listings.csv
# Appended data to ./merge/merged_the-hague.csv
# Starting merge process for jersey-city
# Processing: ./clean/calendar2/Clean_jersey-city.csv and ./all/listings\2023_09_jersey-city_nj_united-states_listings.csv
# Saved new data to ./merge/merged_jersey-city.csv
# Processing: ./clean/calendar2/Clean_jersey-city.csv and ./all/listings\2023_06_jersey-city_nj_united-states_listings.csv
# Appended data to ./merge/merged_jersey-city.csv
# Processing: ./clean/calendar2/Clean_jersey-city.csv and ./all/listings\2023_03_jersey-city_nj_united-states_listings.csv
# Appended data to ./merge/merged_jersey-city.csv
# Processing: ./clean/calendar2/Clean_jersey-city.csv and ./all/listings\2022_12_jersey-city_nj_united-states_listings.csv
# Appended data to ./merge/merged_jersey-city.csv
# Processing: ./clean/calendar2/Clean_jersey-city.csv and ./all/listings\2022_09_jersey-city_nj_united-states_listings.csv
# Appended data to ./merge/merged_jersey-city.csv
# Starting merge process for greater-manchester
# Processing: ./clean/calendar2/Clean_greater-manchester.csv and ./all/listings\2023_09_greater-manchester_england_united-kingdom_listings.csv
# Saved new data to ./merge/merged_greater-manchester.csv
# Processing: ./clean/calendar2/Clean_greater-manchester.csv and ./all/listings\2023_06_greater-manchester_england_united-kingdom_listings.csv
# Appended data to ./merge/merged_greater-manchester.csv
# Processing: ./clean/calendar2/Clean_greater-manchester.csv and ./all/listings\2023_03_greater-manchester_england_united-kingdom_listings.csv
# Appended data to ./merge/merged_greater-manchester.csv
# Processing: ./clean/calendar2/Clean_greater-manchester.csv and ./all/listings\2022_12_greater-manchester_england_united-kingdom_listings.csv
# Appended data to ./merge/merged_greater-manchester.csv
# Processing: ./clean/calendar2/Clean_greater-manchester.csv and ./all/listings\2022_09_greater-manchester_england_united-kingdom_listings.csv
# Appended data to ./merge/merged_greater-manchester.csv
# Starting merge process for edinburgh
# Processing: ./clean/calendar2/Clean_edinburgh.csv and ./all/listings\2023_09_edinburgh_scotland_united-kingdom_listings.csv
# Saved new data to ./merge/merged_edinburgh.csv
# Processing: ./clean/calendar2/Clean_edinburgh.csv and ./all/listings\2023_06_edinburgh_scotland_united-kingdom_listings.csv
# Appended data to ./merge/merged_edinburgh.csv
# Processing: ./clean/calendar2/Clean_edinburgh.csv and ./all/listings\2023_03_edinburgh_scotland_united-kingdom_listings.csv
# Appended data to ./merge/merged_edinburgh.csv
# Processing: ./clean/calendar2/Clean_edinburgh.csv and ./all/listings\2022_12_edinburgh_scotland_united-kingdom_listings.csv
# Appended data to ./merge/merged_edinburgh.csv
# Processing: ./clean/calendar2/Clean_edinburgh.csv and ./all/listings\2022_09_edinburgh_scotland_united-kingdom_listings.csv
# Appended data to ./merge/merged_edinburgh.csv
# Starting merge process for vancouver
# Processing: ./clean/calendar2/Clean_vancouver.csv and ./all/listings\2023_09_vancouver_bc_canada_listings.csv
# Saved new data to ./merge/merged_vancouver.csv
# Processing: ./clean/calendar2/Clean_vancouver.csv and ./all/listings\2023_06_vancouver_bc_canada_listings.csv
# Appended data to ./merge/merged_vancouver.csv
# Processing: ./clean/calendar2/Clean_vancouver.csv and ./all/listings\2023_03_vancouver_bc_canada_listings.csv
# Appended data to ./merge/merged_vancouver.csv
# Processing: ./clean/calendar2/Clean_vancouver.csv and ./all/listings\2022_12_vancouver_bc_canada_listings.csv
# Appended data to ./merge/merged_vancouver.csv
# Processing: ./clean/calendar2/Clean_vancouver.csv and ./all/listings\2022_09_vancouver_bc_canada_listings.csv
# Appended data to ./merge/merged_vancouver.csv
# Starting merge process for sydney
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2023_09_sydney_nsw_australia_listings.csv
# Saved new data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2023_06_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2023_03_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2022_12_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2022_09_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2022_06_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2022_03_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2021_12_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2021_09_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Processing: ./clean/calendar2/Clean_sydney.csv and ./all/listings\2021_06_sydney_nsw_australia_listings.csv
# Appended data to ./merge/merged_sydney.csv
# Starting merge process for fort-worth
# Processing: ./clean/calendar2/Clean_fort-worth.csv and ./all/listings\2023_09_fort-worth_tx_united-states_listings.csv
# Saved new data to ./merge/merged_fort-worth.csv
# Processing: ./clean/calendar2/Clean_fort-worth.csv and ./all/listings\2023_06_fort-worth_tx_united-states_listings.csv
# Appended data to ./merge/merged_fort-worth.csv
# Processing: ./clean/calendar2/Clean_fort-worth.csv and ./all/listings\2023_03_fort-worth_tx_united-states_listings.csv
# Appended data to ./merge/merged_fort-worth.csv
# Processing: ./clean/calendar2/Clean_fort-worth.csv and ./all/listings\2022_12_fort-worth_tx_united-states_listings.csv
# Appended data to ./merge/merged_fort-worth.csv
# Processing: ./clean/calendar2/Clean_fort-worth.csv and ./all/listings\2022_09_fort-worth_tx_united-states_listings.csv
# Appended data to ./merge/merged_fort-worth.csv
# Starting merge process for girona
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2023_09_girona_catalonia_spain_listings.csv
# Saved new data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2023_06_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2023_03_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2022_12_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2022_09_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2022_06_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2022_03_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2021_12_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv
# Processing: ./clean/calendar2/Clean_girona.csv and ./all/listings\2021_09_girona_catalonia_spain_listings.csv
# Appended data to ./merge/merged_girona.csv

# %%
import pandas as pd
import numpy as np
import os
import re

# Define the directory paths
input_dir = './merge/'
output_dir = './2022_data/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Define the columns to keep
columns_to_keep = ['listing_id', 'date', 'available', 'price', 'price_change_count', 'change_in_availability', 'month', 
                'quarter', 'monthly_availability_count', 'quarterly_availability_count', 'monthly_weekend_availability',
                'price_usd', 'name_c', 'description_c', 'neighborhood_overview_c', 'is_weekend', 'minimum_nights', 'maximum_nights', 
                'host_listings_count_airbnb', 'host_id', 'host_since', 'host_about_c', 'host_response_time', 'host_response_rate', 
                'host_acceptance_rate', 'host_is_superhost', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 
                'neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities_count', 
                'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 
                'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 
                'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 
                'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 
                'license', 'instant_bookable', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 
                'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
        ]

# Function to convert percentage strings to decimals
def percentage_to_decimal(s):
    if isinstance(s, str) and s.endswith('%'):
        return float(s.strip('%')) / 100
    return s

# Function to process each file
def process_file(file_path):
    city_name = re.search(r'merged_(.+)\.csv', file_path).group(1)
    data = pd.read_csv(file_path, parse_dates=['date'], low_memory=False)
    
    # Filter rows by date range
    mask = (data['date'] >= '2021-12-01') & (data['date'] <= '2022-12-31')
    data = data.loc[mask]
    
    # Keep only the specified columns
    data = data[columns_to_keep]
    
    # Replace missing values with zeros instead of dropping rows
    data[columns_to_keep] = data[columns_to_keep].fillna(0)
    
    # Convert 'host_acceptance_rate' from percentage to decimal
    data['host_acceptance_rate'] = data['host_acceptance_rate'].apply(percentage_to_decimal)

    # Check and convert 'host_has_profile_pic' from 't'/'f' to 1/0 if necessary
    if 'host_has_profile_pic' in data.columns:
        unique_values = data['host_has_profile_pic'].dropna().unique()
        if all(val in ['t', 'f'] for val in unique_values):
            data['host_has_profile_pic'] = data['host_has_profile_pic'].map({'t': 1, 'f': 0})
        elif any(val not in [1, 0] for val in unique_values):
            print(f"Warning: Unexpected values in 'host_has_profile_pic' column in {file_path}")

    # Data Cleaning and Feature Engineering
    data['host_since_days'] = (pd.to_datetime('today') - pd.to_datetime(data['host_since'])).dt.days
    data['first_review_days'] = (pd.to_datetime('today') - pd.to_datetime(data['first_review'])).dt.days
    data['last_review_days'] = (pd.to_datetime('today') - pd.to_datetime(data['last_review'])).dt.days
    
    # Save the filtered data
    output_file_path = os.path.join(output_dir, f'final_2022_{city_name}.csv')
    data.to_csv(output_file_path, index=False)
    print(f"Processed and saved: {output_file_path}")

# Process each file in the input directory
for file_name in os.listdir(input_dir):
    if file_name.startswith('merged_') and file_name.endswith('.csv'):
        process_file(os.path.join(input_dir, file_name))

print("Processing complete!")
# Out:
# Processed and saved: ./2022_data/final_2022_albany.csv
# Processed and saved: ./2022_data/final_2022_amsterdam.csv
# Processed and saved: ./2022_data/final_2022_antwerp.csv
# Processed and saved: ./2022_data/final_2022_asheville.csv
# Processed and saved: ./2022_data/final_2022_athens.csv
# Processed and saved: ./2022_data/final_2022_austin.csv
# Processed and saved: ./2022_data/final_2022_bangkok.csv
# Processed and saved: ./2022_data/final_2022_barcelona.csv
# Processed and saved: ./2022_data/final_2022_barossa-valley.csv
# Processed and saved: ./2022_data/final_2022_barwon-south-west-vic.csv
# Processed and saved: ./2022_data/final_2022_belize.csv
# Processed and saved: ./2022_data/final_2022_bergamo.csv
# Processed and saved: ./2022_data/final_2022_berlin.csv
# Processed and saved: ./2022_data/final_2022_bologna.csv
# Processed and saved: ./2022_data/final_2022_bordeaux.csv
# Processed and saved: ./2022_data/final_2022_boston.csv
# Processed and saved: ./2022_data/final_2022_bozeman.csv
# Processed and saved: ./2022_data/final_2022_bristol.csv
# Processed and saved: ./2022_data/final_2022_broward-county.csv
# Processed and saved: ./2022_data/final_2022_brussels.csv
# Processed and saved: ./2022_data/final_2022_buenos-aires.csv
# Processed and saved: ./2022_data/final_2022_cambridge.csv
# Processed and saved: ./2022_data/final_2022_cape-town.csv
# Processed and saved: ./2022_data/final_2022_chicago.csv
# Processed and saved: ./2022_data/final_2022_clark-county-nv.csv
# Processed and saved: ./2022_data/final_2022_columbus.csv
# Processed and saved: ./2022_data/final_2022_copenhagen.csv
# Processed and saved: ./2022_data/final_2022_crete.csv
# Processed and saved: ./2022_data/final_2022_dallas.csv
# Processed and saved: ./2022_data/final_2022_denver.csv
# Processed and saved: ./2022_data/final_2022_dublin.csv
# Processed and saved: ./2022_data/final_2022_edinburgh.csv
# Processed and saved: ./2022_data/final_2022_euskadi.csv
# Processed and saved: ./2022_data/final_2022_florence.csv
# Processed and saved: ./2022_data/final_2022_fort-worth.csv
# Processed and saved: ./2022_data/final_2022_geneva.csv
# Processed and saved: ./2022_data/final_2022_ghent.csv
# Processed and saved: ./2022_data/final_2022_girona.csv
# Processed and saved: ./2022_data/final_2022_greater-manchester.csv
# Processed and saved: ./2022_data/final_2022_hawaii.csv
# Processed and saved: ./2022_data/final_2022_hong-kong.csv
# Processed and saved: ./2022_data/final_2022_istanbul.csv
# Processed and saved: ./2022_data/final_2022_jersey-city.csv
# Processed and saved: ./2022_data/final_2022_lisbon.csv
# Processed and saved: ./2022_data/final_2022_london.csv
# Processed and saved: ./2022_data/final_2022_los-angeles.csv
# Processed and saved: ./2022_data/final_2022_lyon.csv
# Processed and saved: ./2022_data/final_2022_madrid.csv
# Processed and saved: ./2022_data/final_2022_malaga.csv
# Processed and saved: ./2022_data/final_2022_mallorca.csv
# Processed and saved: ./2022_data/final_2022_melbourne.csv
# Processed and saved: ./2022_data/final_2022_menorca.csv
# Processed and saved: ./2022_data/final_2022_mexico-city.csv
# Processed and saved: ./2022_data/final_2022_mid-north-coast.csv
# Processed and saved: ./2022_data/final_2022_milan.csv
# Processed and saved: ./2022_data/final_2022_montreal.csv
# Processed and saved: ./2022_data/final_2022_mornington-peninsula.csv
# Processed and saved: ./2022_data/final_2022_munich.csv
# Processed and saved: ./2022_data/final_2022_naples.csv
# Processed and saved: ./2022_data/final_2022_nashville.csv
# Processed and saved: ./2022_data/final_2022_new-brunswick.csv
# Processed and saved: ./2022_data/final_2022_new-orleans.csv
# Processed and saved: ./2022_data/final_2022_new-york-city.csv
# Processed and saved: ./2022_data/final_2022_newark.csv
# Processed and saved: ./2022_data/final_2022_northern-rivers.csv
# Processed and saved: ./2022_data/final_2022_oakland.csv
# Processed and saved: ./2022_data/final_2022_oslo.csv
# Processed and saved: ./2022_data/final_2022_pacific-grove.csv
# Processed and saved: ./2022_data/final_2022_paris.csv
# Processed and saved: ./2022_data/final_2022_pays-basque.csv
# Processed and saved: ./2022_data/final_2022_portland.csv
# Processed and saved: ./2022_data/final_2022_porto.csv
# Processed and saved: ./2022_data/final_2022_prague.csv
# Processed and saved: ./2022_data/final_2022_puglia.csv
# Processed and saved: ./2022_data/final_2022_quebec-city.csv
# Processed and saved: ./2022_data/final_2022_rhode-island.csv
# Processed and saved: ./2022_data/final_2022_riga.csv
# Processed and saved: ./2022_data/final_2022_rio-de-janeiro.csv
# Processed and saved: ./2022_data/final_2022_rome.csv
# Processed and saved: ./2022_data/final_2022_rotterdam.csv
# Processed and saved: ./2022_data/final_2022_salem-or.csv
# Processed and saved: ./2022_data/final_2022_san-diego.csv
# Processed and saved: ./2022_data/final_2022_san-francisco.csv
# Processed and saved: ./2022_data/final_2022_san-mateo-county.csv
# Processed and saved: ./2022_data/final_2022_santa-clara-county.csv
# Processed and saved: ./2022_data/final_2022_santa-cruz-county.csv
# Processed and saved: ./2022_data/final_2022_santiago.csv
# Processed and saved: ./2022_data/final_2022_seattle.csv
# Processed and saved: ./2022_data/final_2022_sevilla.csv
# Processed and saved: ./2022_data/final_2022_sicily.csv
# Processed and saved: ./2022_data/final_2022_singapore.csv
# Processed and saved: ./2022_data/final_2022_south-aegean.csv
# Processed and saved: ./2022_data/final_2022_stockholm.csv
# Processed and saved: ./2022_data/final_2022_sydney.csv
# Processed and saved: ./2022_data/final_2022_taipei.csv
# Processed and saved: ./2022_data/final_2022_tasmania.csv
# Processed and saved: ./2022_data/final_2022_the-hague.csv
# Processed and saved: ./2022_data/final_2022_thessaloniki.csv
# Processed and saved: ./2022_data/final_2022_tokyo.csv
# Processed and saved: ./2022_data/final_2022_toronto.csv
# Processed and saved: ./2022_data/final_2022_trentino.csv
# Processed and saved: ./2022_data/final_2022_twin-cities-msa.csv
# Processed and saved: ./2022_data/final_2022_valencia.csv
# Processed and saved: ./2022_data/final_2022_vancouver.csv
# Processed and saved: ./2022_data/final_2022_vaud.csv
# Processed and saved: ./2022_data/final_2022_venice.csv
# Processed and saved: ./2022_data/final_2022_victoria.csv
# Processed and saved: ./2022_data/final_2022_vienna.csv
# Processed and saved: ./2022_data/final_2022_washington-dc.csv
# Processed and saved: ./2022_data/final_2022_western-australia.csv
# Processed and saved: ./2022_data/final_2022_winnipeg.csv
# Processed and saved: ./2022_data/final_2022_zurich.csv
# Processing complete!

# %%
import pandas as pd
import numpy as np
import os
import re

# Define the directory paths
input_dir = './merge/'
output_dir = './2023_data/'

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Define the columns to keep
columns_to_keep = ['listing_id', 'date', 'available', 'price', 'price_change_count', 'change_in_availability', 'month', 
                'quarter', 'monthly_availability_count', 'quarterly_availability_count', 'monthly_weekend_availability',
                'price_usd', 'name_c', 'description_c', 'neighborhood_overview_c', 'is_weekend', 'minimum_nights', 'maximum_nights', 
                'host_listings_count_airbnb', 'host_id', 'host_since', 'host_about_c', 'host_response_time', 'host_response_rate', 
                'host_acceptance_rate', 'host_is_superhost', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 
                'neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities_count', 
                'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 
                'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 
                'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 
                'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 
                'license', 'instant_bookable', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 
                'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
        ]

# Function to convert percentage strings to decimals
def percentage_to_decimal(s):
    if isinstance(s, str) and s.endswith('%'):
        return float(s.strip('%')) / 100
    return s

# Function to process each file
def process_file(file_path):
    city_name = re.search(r'merged_(.+)\.csv', file_path).group(1)
    data = pd.read_csv(file_path, parse_dates=['date'], low_memory=False)
    
    # Filter rows by date range
    mask = (data['date'] >= '2023-01-01') & (data['date'] <= '2023-09-01')
    data = data.loc[mask]
    
    # Keep only the specified columns
    data = data[columns_to_keep]
    
    # Replace missing values with zeros instead of dropping rows
    data[columns_to_keep] = data[columns_to_keep].fillna(0)
    
    # Convert 'host_acceptance_rate' from percentage to decimal
    data['host_acceptance_rate'] = data['host_acceptance_rate'].apply(percentage_to_decimal)

    # Check and convert 'host_has_profile_pic' from 't'/'f' to 1/0 if necessary
    if 'host_has_profile_pic' in data.columns:
        unique_values = data['host_has_profile_pic'].dropna().unique()
        if all(val in ['t', 'f'] for val in unique_values):
            data['host_has_profile_pic'] = data['host_has_profile_pic'].map({'t': 1, 'f': 0})
        elif any(val not in [1, 0] for val in unique_values):
            print(f"Warning: Unexpected values in 'host_has_profile_pic' column in {file_path}")

    # Data Cleaning and Feature Engineering
    data['host_since_days'] = (pd.to_datetime('today') - pd.to_datetime(data['host_since'], errors='coerce')).dt.days
    data['first_review_days'] = (pd.to_datetime('today') - pd.to_datetime(data['first_review'], errors='coerce')).dt.days
    data['last_review_days'] = (pd.to_datetime('today') - pd.to_datetime(data['last_review'], errors='coerce')).dt.days

    # Replace NaN values with 0
    data[['host_since_days', 'first_review_days', 'last_review_days']] = data[['host_since_days', 'first_review_days', 'last_review_days']].fillna(0)

    
    # Save the filtered data
    output_file_path = os.path.join(output_dir, f'final_2023_{city_name}.csv')
    data.to_csv(output_file_path, index=False)
    print(f"Processed and saved: {output_file_path}")

# Process each file in the input directory
for file_name in os.listdir(input_dir):
    if file_name.startswith('merged_') and file_name.endswith('.csv'):
        process_file(os.path.join(input_dir, file_name))

print("Processing complete!")
# Out:
# Processed and saved: ./2023_data/final_2023_albany.csv
# Processed and saved: ./2023_data/final_2023_amsterdam.csv
