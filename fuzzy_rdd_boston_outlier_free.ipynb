# %%
import pandas as pd
import numpy as np
import category_encoders as ce
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from collections import Counter
import ast
from ast import literal_eval
from scipy.stats import gaussian_kde
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %% [markdown]
# # Step 1: Merge Data

# %%
# Paths to the files are given by the user
calendar_files = {
    '2022_09': '2022_09_calendar.csv',
    '2022_12': '2022_12_calendar.csv',
    '2023_03': '2023_03_calendar.csv',
    '2023_06': '2023_06_calendar.csv',
    '2023_09': '2023_09_calendar.csv',
}

listings_files = {
    '2022_09': '2022_09_listings.csv',
    '2022_12': '2022_12_listings.csv',
    '2023_03': '2023_03_listings.csv',
    '2023_06': '2023_06_listings.csv',
    '2023_09': '2023_09_listings.csv',
}

# Initialize an empty DataFrame to hold the merged data
merged_data = pd.DataFrame()

for period in calendar_files:
    calendar_path = calendar_files[period]
    listings_path = listings_files[period]

    # Read the calendar and listings data
    calendar_df = pd.read_csv(calendar_path)
    listings_df = pd.read_csv(listings_path)

    # Convert 'date' in calendar_df to datetime and ensure IDs are of the same type
    calendar_df['date'] = pd.to_datetime(calendar_df['date']).dt.date
    calendar_df['listing_id'] = calendar_df['listing_id'].astype(str)
    listings_df['id'] = listings_df['id'].astype(str)

    # Create a 'price_listing' column in listings data
    listings_df['price_listing'] = listings_df['price']
    listings_df['minimum_nights_listing'] = listings_df['minimum_nights']
    listings_df['maximum_nights_listing'] = listings_df['maximum_nights']

    # Keep only necessary columns from calendar and listings data
    calendar_df = calendar_df[['listing_id', 'date', 'available', 'price', 'minimum_nights', 'maximum_nights']]
    listings_columns_to_keep = [
        'id',  # Unique identifier for the listing
        'price_listing',  # Assuming this is the target variable: price
        'minimum_nights_listing',  # Minimum nights required to book
        'maximum_nights_listing',  # Maximum nights available to book
        'host_since',  # Date when the host started on Airbnb
        'host_verifications',  # Types of host verification
        'host_acceptance_rate',  # Rate at which the host accepts booking requests
        'host_is_superhost',  # Whether the host has Superhost status
        'neighbourhood_cleansed',  # Normalized location information
        'property_type',  # Type of property being offered
        'room_type',  # Type of room being offered
        'accommodates',  # Number of guests the listing can accommodate
        'bathrooms_text',  # Description of bathrooms available
        'bedrooms',  # Number of bedrooms included in the listing
        'beds',  # Number of beds included in the listing
        'amenities',  # Amenities offered with the listing
        'license',  # The license or registration number
        'number_of_reviews',  # Total number of reviews
        'number_of_reviews_l30d',  # Number of reviews in the last 30 days
        'review_scores_rating',  # Overall rating score given by reviewers
        'availability_30',  # Availability over the next 30 days
        'availability_60',  # Availability over the next 60 days
        'availability_90',  # Availability over the next 90 days
        'availability_365',  # Availability over the next 365 days
        'instant_bookable',  # Indicates if the listing can be booked instantly
        'calculated_host_listings_count',  # Number of listings the host has in total
        'host_response_time',  # Average time the host takes to respond to messages
        'host_response_rate',  # Percentage of messages the host responds to
        'host_listings_count',  # Number of listings a host manages (from my original list)
        'host_identity_verified',  # Whether the host's identity has been verified (from my original list)
        'review_scores_accuracy',  # Accuracy of the listing description as rated by reviewers (from my original list)
        'review_scores_cleanliness',  # Cleanliness score as rated by reviewers (from my original list)
        'review_scores_checkin',  # Check-in experience score as rated by reviewers (from my original list)
        'review_scores_communication',  # Communication score as rated by reviewers (from my original list)
        'review_scores_location',  # Location score as rated by reviewers (from my original list)
        'review_scores_value',  # Value score as rated by reviewers (from my original list)
        'reviews_per_month'  # Average number of reviews per month (from my original list)
    ]

    listings_df = listings_df[listings_columns_to_keep]

    # Find missing IDs and their date range
    missing_ids = set(listings_df['id']) - set(calendar_df['listing_id'])
    date_range = pd.date_range(start=calendar_df['date'].min(), end=calendar_df['date'].max())

    # For each missing ID, create new rows
    for missing_id in missing_ids:
        listing_details = listings_df[listings_df['id'] == missing_id]
        missing_rows = pd.DataFrame({
            'listing_id': missing_id,
            'date': date_range,
            'available': 'f',
            'price': listing_details['price_listing'].values[0],
            'minimum_nights': listing_details['minimum_nights_listing'].values[0],
            'maximum_nights': listing_details['maximum_nights_listing'].values[0]
        })
        calendar_df = pd.concat([calendar_df, missing_rows], ignore_index=True)

 # Merge calendar data with the corresponding listings data
    period_merged_data = calendar_df.merge(listings_df, how='left', left_on='listing_id', right_on='id')

 # Append the period data to the full merged dataset
    merged_data = pd.concat([merged_data, period_merged_data], ignore_index=True)

# Drop duplicates, if any
merged_data.drop_duplicates(subset=['listing_id', 'date'], keep='last', inplace=True)

# Handle missing values
merged_data.fillna(method='ffill', inplace=True)

# Save the cleaned, merged data to a new CSV file
output_file = 'merged_cleaned_data.csv'
merged_data.to_csv(output_file, index=False)

print(f"Processed data saved to {output_file}")
# Out:
# Processed data saved to merged_cleaned_data.csv

# %% [markdown]
# # Step 2: Data Cleaning Procedures

# %%
# Load the dataset
file_path = 'merged_cleaned_data.csv'  # Replace with your actual file path
data = pd.read_csv(file_path)

# Convert 't' and 'f' to 1 and 0
for col in data.columns:
    unique_values = data[col].dropna().unique()
    if set(unique_values) == {'t', 'f'}:
        data[col] = data[col].map({'t': 1, 'f': 0})

# Convert 'bathrooms_text' to numerical
data['bathrooms'] = data['bathrooms_text'].str.extract('(\d+)').astype(float)

# Count the number of amenities and add as a new column
data['amenities_count'] = data['amenities'].str.count(',') + 1

# Drop the original 'bathrooms_text' and 'amenities' columns
data.drop(columns=['bathrooms_text', 'amenities'], inplace=True)

# Convert specific columns to binary (0 or 1)
data['license'] = data['license'].notna().astype(int)

# Define the date range
data['date'] = pd.to_datetime(data['date'])  # Ensure 'date' is in datetime format
start_date = data['date'].min()  # Get the earliest date from your data
end_date = pd.to_datetime('2023-12-31')  # End of the date range you want to plot

# Add the week/weekend variable based on 'date'
data['weekend'] = (data['date'].dt.dayofweek >= 5).astype(int)  # Encode Saturday and Sunday as 1, other days as 0

# Create the 'month_indicator' categorical variable
data['month_indicator'] = data['date'].dt.month_name()

# Create the 'week_indicator' as an integer representing the week of the year
data['week_indicator'] = data['date'].dt.isocalendar().week

# Convert 'week_indicator' to a string to treat it as a categorical variable for fixed effects
data['week_indicator'] = data['week_indicator'].astype(str)

# Convert 'host_since' to datetime and calculate months to December 31, 2023
end_date = pd.to_datetime('2023-12-31')
data['host_since_mos'] = (end_date.year - pd.to_datetime(data['host_since']).dt.year) * 12 + end_date.month - pd.to_datetime(data['host_since']).dt.month

# Convert 'date' column back to a string in the original format
# Assuming the original format was 'YYYY-MM-DD'
data['date'] = data['date'].dt.strftime('%Y-%m-%d')

# Convert 't' and 'f' to 1 and 0, including 'TRUE' and 'FALSE'
for col in data.columns:
    unique_values = data[col].dropna().unique()
    if set(unique_values) == {'t', 'f'} or set(unique_values) == {True, False}:
        data[col] = data[col].map({'t': 1, 'f': 0, True: 1, False: 0})

# Functions to detect datetime and numeric columns
def is_datetime(col):
    try:
        pd.to_datetime(data[col], errors='raise')
        return True
    except ValueError:
        return False

def is_numeric(col):
    temp_col = data[col].replace('[%\$€£₹¥,;:]', '', regex=True)
    temp_col = pd.to_numeric(temp_col, errors='coerce')
    return pd.notnull(temp_col).any()

# Function to check if a column is binary
def is_binary(col):
    return sorted(data[col].dropna().unique()) == [0, 1]

# Classify columns
numerical_cols = []
categorical_cols = []
dummy_cols = [] 
date_cols = []

for col in data.columns:
    if data[col].dtype == 'object':
        if is_datetime(col):
            date_cols.append(col)
            data[col] = pd.to_datetime(data[col], errors='coerce')
        elif is_numeric(col):
            data[col] = data[col].replace('[%\$€£₹¥,;:]', '', regex=True)
            numerical_cols.append(col)
            data[col] = pd.to_numeric(data[col], errors='coerce')
        else:
            categorical_cols.append(col)
    elif data[col].dtype in ['int64', 'float64']:
        if is_binary(col):
            dummy_cols.append(col)
        else:
            numerical_cols.append(col)
    elif data[col].dtype == 'bool':
        dummy_cols.append(col)
    else:
        # Handle other data types as needed
        # For now, categorizing as 'categorical_cols'
        categorical_cols.append(col)

# # Replace spaces with underscores in categorical column names
# for col in categorical_cols:
#     data.rename(columns={col: col.replace(' ', '_')}, inplace=True)
# # Apply One-hot encode categorical columns+
# data = pd.get_dummies(data, columns=categorical_cols)

# Apply Binary Encoding to categorical columns
# encoder = ce.BinaryEncoder(cols=categorical_cols)
# data_encoded = encoder.fit_transform(data[categorical_cols])

# # Concatenate the encoded columns with the original data, excluding original categorical columns
# data = pd.concat([data.drop(categorical_cols, axis=1), data_encoded], axis=1)

# Output the updated DataFrame structure
print(data.info())

# Output the column types
print("Numerical columns:", numerical_cols)
print("Categorical columns:", categorical_cols)
print("Dummy columns:", dummy_cols)
print("Date columns:", date_cols)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3864359 entries, 0 to 3864358
# Data columns (total 47 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   listing_id                      int64
#  1   date                            datetime64[ns]
#  2   available                       int64
#  3   price                           float64
#  4   minimum_nights                  float64
#  5   maximum_nights                  float64
#  6   id                              int64
#  7   price_listing                   float64
#  8   minimum_nights_listing          int64
#  9   maximum_nights_listing          int64
#  10  host_since                      datetime64[ns]
#  11  host_verifications              object
#  12  host_acceptance_rate            int64
#  13  host_is_superhost               int64
#  14  neighbourhood_cleansed          object
#  15  property_type                   object
#  16  room_type                       object
#  17  accommodates                    int64
#  18  bedrooms                        float64
#  19  beds                            float64
#  20  license                         int64
#  21  number_of_reviews               int64
#  22  number_of_reviews_l30d          int64
#  23  review_scores_rating            float64
#  24  availability_30                 int64
#  25  availability_60                 int64
#  26  availability_90                 int64
#  27  availability_365                int64
#  28  instant_bookable                int64
#  29  calculated_host_listings_count  int64
#  30  host_response_time              object
#  31  host_response_rate              int64
#  32  host_listings_count             int64
#  33  host_identity_verified          int64
#  34  review_scores_accuracy          float64
#  35  review_scores_cleanliness       float64
#  36  review_scores_checkin           float64
#  37  review_scores_communication     float64
#  38  review_scores_location          float64
#  39  review_scores_value             float64
#  40  reviews_per_month               float64
#  41  bathrooms                       float64
#  42  amenities_count                 int64
#  43  weekend                         int64
#  44  month_indicator                 object
#  45  week_indicator                  int64
#  46  host_since_mos                  int64
# dtypes: datetime64[ns](2), float64(15), int64(24), object(6)
# memory usage: 1.4+ GB
# None
# Numerical columns: ['listing_id', 'price', 'minimum_nights', 'maximum_nights', 'id', 'price_listing', 'minimum_nights_listing', 'maximum_nights_listing', 'host_acceptance_rate', 'accommodates', 'bedrooms', 'beds', 'number_of_reviews', 'number_of_reviews_l30d', 'review_scores_rating', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calculated_host_listings_count', 'host_response_rate', 'host_listings_count', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month', 'bathrooms', 'amenities_count', 'week_indicator', 'host_since_mos']
# Categorical columns: ['host_verifications', 'neighbourhood_cleansed', 'property_type', 'room_type', 'host_response_time', 'month_indicator']
# Dummy columns: ['available', 'host_is_superhost', 'license', 'instant_bookable', 'host_identity_verified', 'weekend']
# Date columns: ['date', 'host_since']

# %%
# Display rows where 'bathrooms' is missing
missing_bathrooms_data = data[data['bathrooms'].isna()]
print(missing_bathrooms_data.head())  # Display the first few rows

# Statistical summary of the 'bathrooms' column
print("\nStatistical Summary of 'bathrooms':")
print(data['bathrooms'].describe())
# Out:
#        listing_id       date  available  price  minimum_nights  \
# 21839    13082258 2022-09-15          0   52.0            91.0
# 21840    13082258 2022-09-16          0   52.0            91.0
# 21841    13082258 2022-09-17          0   52.0            91.0
# 21842    13082258 2022-09-18          0   52.0            91.0
# 21843    13082258 2022-09-19          0   52.0            91.0
#
#        maximum_nights        id  price_listing  minimum_nights_listing  \
# 21839          1125.0  13082258           52.0                      91
# 21840          1125.0  13082258           52.0                      91
# 21841          1125.0  13082258           52.0                      91
# 21842          1125.0  13082258           52.0                      91
# 21843          1125.0  13082258           52.0                      91
#
#        maximum_nights_listing  ... review_scores_communication  \
# 21839                    1125  ...                         5.0
# 21840                    1125  ...                         5.0
# 21841                    1125  ...                         5.0
# 21842                    1125  ...                         5.0
# 21843                    1125  ...                         5.0
#
#       review_scores_location  review_scores_value  reviews_per_month  \
# 21839                    5.0                  5.0               0.03
# 21840                    5.0                  5.0               0.03
# 21841                    5.0                  5.0               0.03
# 21842                    5.0                  5.0               0.03
# 21843                    5.0                  5.0               0.03
#
#       bathrooms amenities_count weekend  month_indicator  week_indicator  \
# 21839       NaN              15       0        September              37
# 21840       NaN              15       0        September              37
# 21841       NaN              15       1        September              37
# 21842       NaN              15       1        September              37
# 21843       NaN              15       0        September              38
#
#        host_since_mos
# 21839             106
# 21840             106
# 21841             106
# 21842             106
# 21843             106
#
# [5 rows x 47 columns]
#
# Statistical Summary of 'bathrooms':
# count    3.861716e+06
# mean     1.194080e+00
# std      5.989889e-01
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.600000e+01
# Name: bathrooms, dtype: float64

# %%
# Fill missing values in 'bathrooms' with 0
data['bathrooms'].fillna(0, inplace=True)

# Optionally, check if there are any remaining missing values in 'bathrooms'
missing_bathrooms = data['bathrooms'].isna().sum()
print("Missing values in bathrooms after filling:", missing_bathrooms)
# Out:
# Missing values in bathrooms after filling: 0

# %%
# Save the cleaned data
cleaned_data_path = 'final_boston_data_no_outliers.csv'
data.to_csv(cleaned_data_path, index=False)

# %%
# Load the dataset
file_path = 'final_boston_data_no_outliers.csv'
data = pd.read_csv(file_path)

# %%
# Generate a summary table with two decimal points
summary_table = data.describe(include='all').applymap(lambda x: round(x, 2) if isinstance(x, float) else x)
print(summary_table)
# Out:
#           listing_id        date   available       price  minimum_nights  \
# count   3.864359e+06     3864359  3864359.00  3864359.00      3864359.00
# unique           NaN         731         NaN         NaN             NaN
# top              NaN  2023-08-29         NaN         NaN             NaN
# freq             NaN        6698         NaN         NaN             NaN
# mean    2.614182e+17         NaN        0.52      237.77           65.09
# std     3.576345e+17         NaN        0.50      349.53          134.89
# min     3.168000e+03         NaN        0.00        0.00            1.00
# 25%     2.541631e+07         NaN        0.00       98.00            2.00
# 50%     4.860119e+07         NaN        1.00      174.00           21.00
# 75%     6.522855e+17         NaN        1.00      278.00           91.00
# max     9.804836e+17         NaN        1.00    15300.00          998.00
#
#         maximum_nights            id  price_listing  minimum_nights_listing  \
# count     3.864359e+06  3.864359e+06     3864359.00              3864359.00
# unique             NaN           NaN            NaN                     NaN
# top                NaN           NaN            NaN                     NaN
# freq               NaN           NaN            NaN                     NaN
# mean      2.483183e+06  2.614182e+17         222.55                   29.20
# std       7.297059e+07  3.576345e+17         300.63                   38.34
# min       1.000000e+00  3.168000e+03           0.00                    1.00
# 25%       3.650000e+02  2.541631e+07          95.00                    2.00
# 50%       1.125000e+03  4.860119e+07         166.00                   14.00
# 75%       1.125000e+03  6.522855e+17         260.00                   32.00
# max       2.147484e+09  9.804836e+17       10000.00                  730.00
#
#         maximum_nights_listing  ... review_scores_communication  \
# count               3864359.00  ...                  3864359.00
# unique                     NaN  ...                         NaN
# top                        NaN  ...                         NaN
# freq                       NaN  ...                         NaN
# mean                    656.09  ...                        4.80
# std                     550.77  ...                        0.44
# min                       1.00  ...                        1.00
# 25%                     360.00  ...                        4.80
# 50%                     365.00  ...                        4.94
# 75%                    1125.00  ...                        5.00
# max                   30000.00  ...                        5.00
#
#        review_scores_location  review_scores_value  reviews_per_month  \
# count              3864359.00           3864359.00         3864359.00
# unique                    NaN                  NaN                NaN
# top                       NaN                  NaN                NaN
# freq                      NaN                  NaN                NaN
# mean                     4.76                 4.58               1.82
# std                      0.39                 0.52               2.03
# min                      1.00                 1.00               0.01
# 25%                      4.67                 4.50               0.32
# 50%                      4.89                 4.71               1.05
# 75%                      5.00                 4.89               2.61
# max                      5.00                 5.00              41.14
#
#          bathrooms amenities_count     weekend  month_indicator  \
# count   3864359.00      3864359.00  3864359.00          3864359
# unique         NaN             NaN         NaN               12
# top            NaN             NaN         NaN              May
# freq           NaN             NaN         NaN           334304
# mean          1.19           30.59        0.29              NaN
# std           0.60           14.45        0.45              NaN
# min           0.00            1.00        0.00              NaN
# 25%           1.00           21.00        0.00              NaN
# 50%           1.00           28.00        0.00              NaN
# 75%           1.00           39.00        1.00              NaN
# max          16.00          107.00        1.00              NaN
#
#         week_indicator  host_since_mos
# count       3864359.00      3864359.00
# unique             NaN             NaN
# top                NaN             NaN
# freq               NaN             NaN
# mean             26.39           84.45
# std              14.92           36.03
# min               1.00            4.00
# 25%              14.00           54.00
# 50%              26.00           84.00
# 75%              39.00          110.00
# max              52.00          182.00
#
# [11 rows x 47 columns]

# %%
price = data["price"]

# Interquartile range (IQR)
q1, q3 = np.percentile(price, [25, 75])
IQR = q3 - q1

# Lower and upper bounds for outliers
lower_bound = q1 - 1.5 * IQR
upper_bound = q3 + 1.5 * IQR

# Remove outliers from price data
data["price"] = price[np.where((price >= lower_bound) & (price <= upper_bound))[0]]

# %%
# Generate a summary table with two decimal points
summary_table = data.describe(include='all').applymap(lambda x: round(x, 2) if isinstance(x, float) else x)
print(summary_table)
# Out:
#           listing_id        date   available       price  minimum_nights  \
# count   3.864359e+06     3864359  3864359.00  3613403.00      3864359.00
# unique           NaN         731         NaN         NaN             NaN
# top              NaN  2023-08-29         NaN         NaN             NaN
# freq             NaN        6698         NaN         NaN             NaN
# mean    2.614182e+17         NaN        0.52      184.15           65.09
# std     3.576345e+17         NaN        0.50      113.85          134.89
# min     3.168000e+03         NaN        0.00        0.00            1.00
# 25%     2.541631e+07         NaN        0.00       93.00            2.00
# 50%     4.860119e+07         NaN        1.00      159.00           21.00
# 75%     6.522855e+17         NaN        1.00      250.00           91.00
# max     9.804836e+17         NaN        1.00      548.00          998.00
#
#         maximum_nights            id  price_listing  minimum_nights_listing  \
# count     3.864359e+06  3.864359e+06     3864359.00              3864359.00
# unique             NaN           NaN            NaN                     NaN
# top                NaN           NaN            NaN                     NaN
# freq               NaN           NaN            NaN                     NaN
# mean      2.483183e+06  2.614182e+17         222.55                   29.20
# std       7.297059e+07  3.576345e+17         300.63                   38.34
# min       1.000000e+00  3.168000e+03           0.00                    1.00
# 25%       3.650000e+02  2.541631e+07          95.00                    2.00
# 50%       1.125000e+03  4.860119e+07         166.00                   14.00
# 75%       1.125000e+03  6.522855e+17         260.00                   32.00
# max       2.147484e+09  9.804836e+17       10000.00                  730.00
#
#         maximum_nights_listing  ... review_scores_communication  \
# count               3864359.00  ...                  3864359.00
# unique                     NaN  ...                         NaN
# top                        NaN  ...                         NaN
# freq                       NaN  ...                         NaN
# mean                    656.09  ...                        4.80
# std                     550.77  ...                        0.44
# min                       1.00  ...                        1.00
# 25%                     360.00  ...                        4.80
# 50%                     365.00  ...                        4.94
# 75%                    1125.00  ...                        5.00
# max                   30000.00  ...                        5.00
#
#        review_scores_location  review_scores_value  reviews_per_month  \
# count              3864359.00           3864359.00         3864359.00
# unique                    NaN                  NaN                NaN
# top                       NaN                  NaN                NaN
# freq                      NaN                  NaN                NaN
# mean                     4.76                 4.58               1.82
# std                      0.39                 0.52               2.03
# min                      1.00                 1.00               0.01
# 25%                      4.67                 4.50               0.32
# 50%                      4.89                 4.71               1.05
# 75%                      5.00                 4.89               2.61
# max                      5.00                 5.00              41.14
#
#          bathrooms amenities_count     weekend  month_indicator  \
# count   3864359.00      3864359.00  3864359.00          3864359
# unique         NaN             NaN         NaN               12
# top            NaN             NaN         NaN              May
# freq           NaN             NaN         NaN           334304
# mean          1.19           30.59        0.29              NaN
# std           0.60           14.45        0.45              NaN
# min           0.00            1.00        0.00              NaN
# 25%           1.00           21.00        0.00              NaN
# 50%           1.00           28.00        0.00              NaN
# 75%           1.00           39.00        1.00              NaN
# max          16.00          107.00        1.00              NaN
#
#         week_indicator  host_since_mos
# count       3864359.00      3864359.00
# unique             NaN             NaN
# top                NaN             NaN
# freq               NaN             NaN
# mean             26.39           84.45
# std              14.92           36.03
# min               1.00            4.00
# 25%              14.00           54.00
# 50%              26.00           84.00
# 75%              39.00          110.00
# max              52.00          182.00
#
# [11 rows x 47 columns]

# %%
# Define the date range
data['date'] = pd.to_datetime(data['date'])  # Ensure 'date' is in datetime format
start_date = data['date'].min()  # Get the earliest date from your data
end_date = pd.to_datetime('2023-12-31')  # End of the date range you want to plot

# Filter data for the date range
data = data[(data['date'] >= start_date) & (data['date'] <= end_date)]

# Define cutoff dates for the introduction of the Smart Pricing tool
early_access_start = pd.to_datetime('2023-03-25')
public_availability_start = pd.to_datetime('2023-05-25')

# Plotting
plt.figure(figsize=(15, 7))

# Treatment group plot
sns.lineplot(data=data[data['available'] == 1], x='date', y='price', label='Treatment', ci=None)

# Control group plot
sns.lineplot(data=data[data['available'] == 0], x='date', y='price', label='Control', ci=None)

# Highlight the policy change dates
plt.axvline(x=pd.to_datetime('2023-03-25'), color='green', linestyle='--', lw=2, label='Early Access Start Date')
plt.axvline(x=pd.to_datetime('2023-05-25'), color='red', linestyle='--', lw=2, label='Public Availability Start Date')

# Improve the legend
plt.legend(title='Group', loc='upper left')

# Title and labels
plt.title('Daily Price Trend for Treatment and Control Groups')
plt.xlabel('Date')
plt.ylabel('Price')

# Tight layout for saving
plt.tight_layout()

# Show plot
plt.show()
# Out:
# C:\Users\yirsu\AppData\Local\Temp\ipykernel_18960\227100694.py:17: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=data[data['available'] == 1], x='date', y='price', label='Treatment', ci=None)
# C:\Users\yirsu\AppData\Local\Temp\ipykernel_18960\227100694.py:20: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=data[data['available'] == 0], x='date', y='price', label='Control', ci=None)

# %%
data['price_smoothed'] = data.groupby('available')['price'].transform(lambda x: x.rolling(14, center=True).mean())

# Plotting
plt.figure(figsize=(15, 7))

# Treatment group plot
sns.lineplot(data=data[data['available'] == 1], x='date', y='price_smoothed', label='Treatment', ci=None)

# Control group plot
sns.lineplot(data=data[data['available'] == 0], x='date', y='price_smoothed', label='Control', ci=None)

# Highlight the policy change dates
plt.axvline(x=pd.to_datetime('2023-03-25'), color='green', linestyle='--', lw=2, label='Early Access Start Date')
plt.axvline(x=pd.to_datetime('2023-05-25'), color='red', linestyle='--', lw=2, label='Public Availability Start Date')

# Improve the legend
plt.legend(title='Group', loc='upper left')

# Title and labels
plt.title('Bi-Weekly Rolling Average Price Trend for Treatment and Control Groups')
plt.xlabel('Date')
plt.ylabel('Bi-Weekly Rolling Average Price')

# Tight layout for saving
plt.tight_layout()

# Show plot
plt.show()
# Out:
# C:\Users\yirsu\AppData\Local\Temp\ipykernel_18960\2056561316.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=data[data['available'] == 1], x='date', y='price_smoothed', label='Treatment', ci=None)
# C:\Users\yirsu\AppData\Local\Temp\ipykernel_18960\2056561316.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=data[data['available'] == 0], x='date', y='price_smoothed', label='Control', ci=None)

# %% [markdown]
# ### IVs should have the following characteristics:
#
# * Strongly correlated with available_dummy (the treatment variable).
# * Not correlated or very weakly correlated with the price (the outcome variable), which is not shown in this correlation matrix but is necessary to check.

# %%
# Exclude non-relevant variables from the correlation matrix
excluded_vars = ['days_from_cutoff', 'listing_id', 'id', 'price_listing', 'minimum_nights_listing', 
                 'maximum_nights_listing']
all_cols = data.columns.tolist()
relevant_cols = [col for col in all_cols if col not in excluded_vars]

# Calculate the correlation matrix
corr_matrix = data[relevant_cols].corr()

# Define thresholds and identify potential IVs
corr_with_treatment_threshold = 0.2 # Min
corr_with_price_threshold = 0.1 # Max
potential_ivs = [col for col in corr_matrix.columns if (col != 'available') and (abs(corr_matrix.loc[col, 'available']) > corr_with_treatment_threshold) and (abs(corr_matrix.loc[col, 'price']) < corr_with_price_threshold)]

# Plot the final correlation matrix heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix.loc[potential_ivs + ['price', 'available'], potential_ivs + ['price', 'available']], annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix with Potential IVs, Available, and Price")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
print(potential_ivs)
# Out:
# ['availability_30', 'availability_60', 'availability_90', 'availability_365']

# %%
ivs = ['availability_30', 'availability_60', 'availability_90', 'availability_365']

# %%
excluded_vars = ['days_from_cutoff', 'listing_id', 'id', 'price_listing', 'minimum_nights_listing', 
                 'maximum_nights_listing','price_smoothed']

excluded_vars = excluded_vars + potential_ivs

# Initialize a list to store variables with high correlation
control_vars_1st = []

# Define the correlation threshold
corr_threshold = 0.05

# Calculate correlations for each numeric variable in the DataFrame
for var in data.columns:
    if var in excluded_vars or not pd.api.types.is_numeric_dtype(data[var]):
        continue
    corr_with_available = data['available'].corr(data[var])
    if abs(corr_with_available) >= corr_threshold:
        control_vars_1st.append(var)

# Calculate and plot the final correlation matrix for the selected high correlation variables
final_corr_matrix = data[control_vars_1st].corr()

# Plot the final heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(final_corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title("Correlation Matrix with Variables Highly Correlated with 'available'")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Display the list of variables with high correlation
print("Variables with high correlation to 'available':", control_vars_1st)
# Out:
# Variables with high correlation to 'available': ['available', 'price', 'host_acceptance_rate', 'host_is_superhost', 'instant_bookable', 'review_scores_accuracy', 'review_scores_communication', 'review_scores_value', 'week_indicator', 'host_since_mos']

# %%
control_vars_1st = ['host_since_mos', 'host_acceptance_rate', 'host_is_superhost', 'instant_bookable', 'host_listings_count','review_scores_accuracy',
                    'review_scores_cleanliness','review_scores_communication','review_scores_location','review_scores_value','reviews_per_month']

# %%
# Initialize a list to store variables with high correlation
control_vars_2nd = []

# Define the correlation threshold
corr_threshold = 0.10

# Calculate correlations for each numeric variable in the DataFrame
for var in data.columns:
    if var in excluded_vars or not pd.api.types.is_numeric_dtype(data[var]):
        continue
    corr_with_available = data['price'].corr(data[var])
    if abs(corr_with_available) >= corr_threshold:
        control_vars_2nd.append(var)

# Calculate and plot the final correlation matrix for the selected high correlation variables
final_corr_matrix = data[control_vars_2nd].corr()

# Plot the final heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(final_corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title("Correlation Matrix with Variables Highly Correlated with 'price'")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Display the list of variables with high correlation
print("Variables with high correlation to 'price':", control_vars_2nd)
# Out:
# Variables with high correlation to 'price': ['price', 'host_acceptance_rate', 'accommodates', 'bedrooms', 'beds', 'host_listings_count', 'review_scores_location', 'bathrooms', 'amenities_count']

# %%
control_vars_2nd = ['accommodates', 'bedrooms', 'beds', 'bathrooms', 'amenities_count', 'weekend', 'instant_bookable']

# %% [markdown]
# # Fuzzy RDD

# %%
# Define the cutoff date for early access to the smart pricing tool
cutoff_date = pd.to_datetime('2023-03-25')

# Convert 'date' to a numerical format (e.g., days since the start)
data['date_numeric'] = (data['date'] - data['date'].min()).dt.days

# Estimate the density at the cutoff
kde = gaussian_kde(data['date_numeric'])
density_at_cutoff = kde(cutoff_date.toordinal() - data['date'].min().toordinal())

# Calculate bandwidth using a rule (e.g., Silverman's rule)
bandwidth = 3 * min(np.std(data['date_numeric']), np.quantile(data['date_numeric'], 0.75) - np.quantile(data['date_numeric'], 0.25)) * len(data['date_numeric']) ** (-1/5)

# Create a binary variable for treatment assignment based on the cutoff date
data['post_cutoff'] = (data['date'] > cutoff_date).astype(int)
data['treatment_probability'] = data['available'] * data['post_cutoff']

# First stage: Estimate the propensity score
formula_1st_stage = 'treatment_probability ~ C(host_verifications) + C(host_response_time) + ' + ' + '.join(ivs) + ' + ' + ' + '.join(control_vars_1st)
model_1st_stage = smf.logit(formula_1st_stage, data=data).fit(cov_type='HC3')
data['Prob_Smart_Pricing_Tool'] = model_1st_stage.predict()

# Print the results
print(model_1st_stage.summary())

# Filter data within the bandwidth of the cutoff
bandwidth_filter = (data['date_numeric'] >= (cutoff_date.toordinal() - data['date'].min().toordinal() - bandwidth)) & (data['date_numeric'] <= (cutoff_date.toordinal() - data['date'].min().toordinal() + bandwidth))
data_bandwidth = data[bandwidth_filter]

# Include fixed effects for 'week_indicator'
formula_2nd_stage = 'price ~ Prob_Smart_Pricing_Tool + C(month_indicator) + C(week_indicator) + C(room_type) + C(neighbourhood_cleansed) + ' + ' + '.join(control_vars_2nd)
model_2nd_stage = smf.ols(formula_2nd_stage, data=data_bandwidth).fit(cov_type='HC3')

# Print the results
print(model_2nd_stage.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.516438
#          Iterations 6
#                              Logit Regression Results
# =================================================================================
# Dep. Variable:     treatment_probability   No. Observations:              2727480
# Model:                             Logit   Df Residuals:                  2727456
# Method:                              MLE   Df Model:                           23
# Date:                   Mon, 18 Dec 2023   Pseudo R-squ.:                  0.1646
# Time:                           14:07:08   Log-Likelihood:            -1.4086e+06
# converged:                          True   LL-Null:                   -1.6861e+06
# Covariance Type:                     HC3   LLR p-value:                     0.000
# ====================================================================================================================
#                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           -2.3967      0.028    -86.079      0.000      -2.451      -2.342
# C(host_verifications)[T.['email', 'phone']]          0.0745      0.005     16.001      0.000       0.065       0.084
# C(host_verifications)[T.['email']]                  -0.1376      0.076     -1.807      0.071      -0.287       0.012
# C(host_verifications)[T.['phone', 'work_email']]    -0.2701      0.039     -6.926      0.000      -0.347      -0.194
# C(host_verifications)[T.['phone']]                   0.2272      0.008     29.774      0.000       0.212       0.242
# C(host_verifications)[T.[]]                          0.4237      0.146      2.909      0.004       0.138       0.709
# C(host_response_time)[T.within a day]                0.2604      0.016     16.034      0.000       0.229       0.292
# C(host_response_time)[T.within a few hours]          0.7242      0.016     46.541      0.000       0.694       0.755
# C(host_response_time)[T.within an hour]              0.4089      0.015     26.441      0.000       0.379       0.439
# availability_30                                      0.0049      0.000     12.055      0.000       0.004       0.006
# availability_60                                     -0.0070      0.000    -16.992      0.000      -0.008      -0.006
# availability_90                                      0.0188      0.000     88.711      0.000       0.018       0.019
# availability_365                                     0.0056   1.57e-05    357.239      0.000       0.006       0.006
# host_since_mos                                      -0.0023   4.56e-05    -51.401      0.000      -0.002      -0.002
# host_acceptance_rate                                 0.0011   8.21e-05     12.925      0.000       0.001       0.001
# host_is_superhost                                    0.0339      0.004      8.999      0.000       0.027       0.041
# instant_bookable                                    -0.1005      0.003    -31.433      0.000      -0.107      -0.094
# host_listings_count                              -2.306e-05   1.57e-06    -14.652      0.000   -2.61e-05      -2e-05
# review_scores_accuracy                              -0.0175      0.006     -3.143      0.002      -0.028      -0.007
# review_scores_cleanliness                           -0.0217      0.005     -4.671      0.000      -0.031      -0.013
# review_scores_communication                         -0.0125      0.005     -2.575      0.010      -0.022      -0.003
# review_scores_location                              -0.0489      0.004    -11.249      0.000      -0.057      -0.040
# review_scores_value                                 -0.0631      0.004    -14.036      0.000      -0.072      -0.054
# reviews_per_month                                   -0.0108      0.001    -14.061      0.000      -0.012      -0.009
# ====================================================================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.567
# Model:                            OLS   Adj. R-squared:                  0.567
# Method:                 Least Squares   F-statistic:                     8174.
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):               0.00
# Time:                        14:07:13   Log-Likelihood:            -1.3673e+06
# No. Observations:              240375   AIC:                         2.735e+06
# Df Residuals:                  240331   BIC:                         2.735e+06
# Df Model:                          43
# Covariance Type:                  HC3
# ========================================================================================================================
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                               58.8014      1.632     36.039      0.000      55.604      61.999
# C(month_indicator)[T.March]                             -6.8570      0.845     -8.115      0.000      -8.513      -5.201
# C(week_indicator)[T.10]                                  5.4953      1.055      5.210      0.000       3.428       7.563
# C(week_indicator)[T.11]                                  7.3356      1.055      6.952      0.000       5.268       9.404
# C(week_indicator)[T.12]                                  1.8541      1.048      1.769      0.077      -0.200       3.908
# C(week_indicator)[T.13]                                  2.8031      1.102      2.545      0.011       0.644       4.962
# C(week_indicator)[T.14]                                  5.1411      1.425      3.607      0.000       2.347       7.935
# C(week_indicator)[T.15]                                  9.5052      1.506      6.311      0.000       6.553      12.457
# C(room_type)[T.Hotel room]                              18.0242      4.443      4.057      0.000       9.316      26.732
# C(room_type)[T.Private room]                           -58.5016      0.405   -144.511      0.000     -59.295     -57.708
# C(room_type)[T.Shared room]                            -86.6669      1.801    -48.115      0.000     -90.197     -83.137
# C(neighbourhood_cleansed)[T.Back Bay]                   43.2827      0.915     47.292      0.000      41.489      45.076
# C(neighbourhood_cleansed)[T.Bay Village]                28.7295      1.550     18.529      0.000      25.691      31.768
# C(neighbourhood_cleansed)[T.Beacon Hill]               -17.0503      0.976    -17.477      0.000     -18.963     -15.138
# C(neighbourhood_cleansed)[T.Brighton]                  -35.9296      0.609    -58.955      0.000     -37.124     -34.735
# C(neighbourhood_cleansed)[T.Charlestown]                -4.8005      0.691     -6.943      0.000      -6.156      -3.445
# C(neighbourhood_cleansed)[T.Chinatown]                  14.7304      1.069     13.774      0.000      12.634      16.826
# C(neighbourhood_cleansed)[T.Dorchester]                -51.4733      0.543    -94.845      0.000     -52.537     -50.410
# C(neighbourhood_cleansed)[T.Downtown]                   43.8232      0.844     51.938      0.000      42.169      45.477
# C(neighbourhood_cleansed)[T.East Boston]               -37.3623      0.654    -57.111      0.000     -38.645     -36.080
# C(neighbourhood_cleansed)[T.Fenway]                     24.0965      0.885     27.240      0.000      22.363      25.830
# C(neighbourhood_cleansed)[T.Harbor Islands]            -20.0987      4.213     -4.771      0.000     -28.356     -11.842
# C(neighbourhood_cleansed)[T.Hyde Park]                 -60.4375      1.232    -49.042      0.000     -62.853     -58.022
# C(neighbourhood_cleansed)[T.Jamaica Plain]             -18.2873      0.875    -20.907      0.000     -20.002     -16.573
# C(neighbourhood_cleansed)[T.Leather District]           13.7262      3.134      4.380      0.000       7.585      19.868
# C(neighbourhood_cleansed)[T.Longwood Medical Area]      13.1279      1.571      8.358      0.000      10.050      16.206
# C(neighbourhood_cleansed)[T.Mattapan]                  -34.4917      1.360    -25.355      0.000     -37.158     -31.825
# C(neighbourhood_cleansed)[T.Mission Hill]              -19.9620      1.032    -19.335      0.000     -21.986     -17.938
# C(neighbourhood_cleansed)[T.North End]                  23.9863      1.622     14.789      0.000      20.807      27.165
# C(neighbourhood_cleansed)[T.Roslindale]                -49.0564      1.053    -46.569      0.000     -51.121     -46.992
# C(neighbourhood_cleansed)[T.Roxbury]                   -40.2746      0.550    -73.189      0.000     -41.353     -39.196
# C(neighbourhood_cleansed)[T.South Boston]                2.5614      0.992      2.583      0.010       0.618       4.505
# C(neighbourhood_cleansed)[T.South Boston Waterfront]    41.4648      1.927     21.515      0.000      37.687      45.242
# C(neighbourhood_cleansed)[T.South End]                  18.0192      0.865     20.840      0.000      16.325      19.714
# C(neighbourhood_cleansed)[T.West End]                   42.2920      1.176     35.952      0.000      39.986      44.598
# C(neighbourhood_cleansed)[T.West Roxbury]              -35.6460      1.608    -22.168      0.000     -38.798     -32.494
# Prob_Smart_Pricing_Tool                                 43.5734      0.832     52.365      0.000      41.943      45.204
# accommodates                                            17.4478      0.184     95.055      0.000      17.088      17.808
# bedrooms                                                 4.5699      0.172     26.623      0.000       4.233       4.906
# beds                                                     4.8819      0.286     17.073      0.000       4.321       5.442
# bathrooms                                               26.8228      0.360     74.450      0.000      26.117      27.529
# amenities_count                                          0.8876      0.013     67.203      0.000       0.862       0.913
# weekend                                                  2.9974      0.393      7.628      0.000       2.227       3.768
# instant_bookable                                        12.1962      0.342     35.693      0.000      11.526      12.866
# ==============================================================================
# Omnibus:                    43157.292   Durbin-Watson:                   0.186
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           103094.607
# Skew:                           1.017   Prob(JB):                         0.00
# Kurtosis:                       5.481   Cond. No.                         793.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
# Robustness check: varying bandwidth
bandwidth_values = np.arange(1.06, 10.1, 0.1)
coefficients = []

for bandwidth in bandwidth_values:
    # Calculate the bandwidth
    calculated_bandwidth = bandwidth * min(np.std(data['date_numeric']), np.quantile(data['date_numeric'], 0.75) - np.quantile(data['date_numeric'], 0.25)) * len(data['date_numeric']) ** (-1/5)

    # Filter data within the bandwidth of the cutoff
    bandwidth_filter = (data['date_numeric'] >= (cutoff_date.toordinal() - data['date'].min().toordinal() - calculated_bandwidth)) & (data['date_numeric'] <= (cutoff_date.toordinal() - data['date'].min().toordinal() + calculated_bandwidth))
    data_bandwidth = data[bandwidth_filter]

    # Second stage regression
    formula_2nd_stage = 'price ~ Prob_Smart_Pricing_Tool + C(month_indicator) + C(week_indicator) + C(room_type) + C(neighbourhood_cleansed) + ' + ' + '.join(control_vars_2nd)
    model_2nd_stage = smf.ols(formula_2nd_stage, data=data_bandwidth).fit(cov_type='HC3')

    # Extract and store the coefficient of interest
    coefficients.append((bandwidth, model_2nd_stage.params['Prob_Smart_Pricing_Tool']))

# Print the results
for bandwidth, coef in coefficients:
    print(f"Bandwidth: {bandwidth:.2f}, Coefficient of Prob_Smart_Pricing_Tool: {coef}")



# Extract bandwidths and coefficients
bandwidths, coeffs = zip(*coefficients)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(bandwidths, coeffs, marker='o')
plt.xlabel('Bandwidth')
plt.ylabel('Coefficient of Prob_Smart_Pricing_Tool')
plt.title('Coefficient of Prob_Smart_Pricing_Tool Across Different Bandwidths')
plt.grid(True)
plt.show()
# Out:
# Bandwidth: 1.06, Coefficient of Prob_Smart_Pricing_Tool: 40.38867988810697
# Bandwidth: 1.16, Coefficient of Prob_Smart_Pricing_Tool: 40.38867988810697
# Bandwidth: 1.26, Coefficient of Prob_Smart_Pricing_Tool: 41.24784915329209
# Bandwidth: 1.36, Coefficient of Prob_Smart_Pricing_Tool: 41.71394775324892
# Bandwidth: 1.46, Coefficient of Prob_Smart_Pricing_Tool: 41.71394775324892
# Bandwidth: 1.56, Coefficient of Prob_Smart_Pricing_Tool: 41.79852655762488
# Bandwidth: 1.66, Coefficient of Prob_Smart_Pricing_Tool: 41.84454361702538
# Bandwidth: 1.76, Coefficient of Prob_Smart_Pricing_Tool: 41.84454361702538
# Bandwidth: 1.86, Coefficient of Prob_Smart_Pricing_Tool: 42.17015083130797
# Bandwidth: 1.96, Coefficient of Prob_Smart_Pricing_Tool: 42.71808796483373
# Bandwidth: 2.06, Coefficient of Prob_Smart_Pricing_Tool: 42.71808796483373
# Bandwidth: 2.16, Coefficient of Prob_Smart_Pricing_Tool: 43.428428418533514
# Bandwidth: 2.26, Coefficient of Prob_Smart_Pricing_Tool: 43.35543673446241
# Bandwidth: 2.36, Coefficient of Prob_Smart_Pricing_Tool: 43.35543673446241
# Bandwidth: 2.46, Coefficient of Prob_Smart_Pricing_Tool: 43.0195385919622
# Bandwidth: 2.56, Coefficient of Prob_Smart_Pricing_Tool: 42.704043436852594
# Bandwidth: 2.66, Coefficient of Prob_Smart_Pricing_Tool: 42.704043436852594
# Bandwidth: 2.76, Coefficient of Prob_Smart_Pricing_Tool: 42.45308738466956
# Bandwidth: 2.86, Coefficient of Prob_Smart_Pricing_Tool: 42.6153352825371
# Bandwidth: 2.96, Coefficient of Prob_Smart_Pricing_Tool: 43.573423974060624
# Bandwidth: 3.06, Coefficient of Prob_Smart_Pricing_Tool: 43.573423974060624
# Bandwidth: 3.16, Coefficient of Prob_Smart_Pricing_Tool: 44.626110209216954
# Bandwidth: 3.26, Coefficient of Prob_Smart_Pricing_Tool: 45.60926182505085
# Bandwidth: 3.36, Coefficient of Prob_Smart_Pricing_Tool: 45.60926182505085
# Bandwidth: 3.46, Coefficient of Prob_Smart_Pricing_Tool: 46.43923658252822
# Bandwidth: 3.56, Coefficient of Prob_Smart_Pricing_Tool: 46.25629534786545
# Bandwidth: 3.66, Coefficient of Prob_Smart_Pricing_Tool: 46.25629534786545
# Bandwidth: 3.76, Coefficient of Prob_Smart_Pricing_Tool: 45.984141923950645
# Bandwidth: 3.86, Coefficient of Prob_Smart_Pricing_Tool: 45.85361941348491
# Bandwidth: 3.96, Coefficient of Prob_Smart_Pricing_Tool: 45.85361941348491
# Bandwidth: 4.06, Coefficient of Prob_Smart_Pricing_Tool: 45.86825853222356
# Bandwidth: 4.16, Coefficient of Prob_Smart_Pricing_Tool: 46.08726419603091
# Bandwidth: 4.26, Coefficient of Prob_Smart_Pricing_Tool: 46.08726419603091
# Bandwidth: 4.36, Coefficient of Prob_Smart_Pricing_Tool: 46.10474172251904
# Bandwidth: 4.46, Coefficient of Prob_Smart_Pricing_Tool: 46.05227183999046
# Bandwidth: 4.56, Coefficient of Prob_Smart_Pricing_Tool: 46.05227183999046
# Bandwidth: 4.66, Coefficient of Prob_Smart_Pricing_Tool: 46.02672232962905
# Bandwidth: 4.76, Coefficient of Prob_Smart_Pricing_Tool: 46.01980033145655
# Bandwidth: 4.86, Coefficient of Prob_Smart_Pricing_Tool: 46.01980033145655
# Bandwidth: 4.96, Coefficient of Prob_Smart_Pricing_Tool: 46.038183261399006
# Bandwidth: 5.06, Coefficient of Prob_Smart_Pricing_Tool: 46.10542358163384
# Bandwidth: 5.16, Coefficient of Prob_Smart_Pricing_Tool: 46.10542358163384
# Bandwidth: 5.26, Coefficient of Prob_Smart_Pricing_Tool: 46.299982737656876
# Bandwidth: 5.36, Coefficient of Prob_Smart_Pricing_Tool: 46.284125626209494
# Bandwidth: 5.46, Coefficient of Prob_Smart_Pricing_Tool: 46.284125626209494
# Bandwidth: 5.56, Coefficient of Prob_Smart_Pricing_Tool: 46.295878948535126
# Bandwidth: 5.66, Coefficient of Prob_Smart_Pricing_Tool: 46.30895671528598
# Bandwidth: 5.76, Coefficient of Prob_Smart_Pricing_Tool: 46.30895671528598
# Bandwidth: 5.86, Coefficient of Prob_Smart_Pricing_Tool: 46.38532953380552
# Bandwidth: 5.96, Coefficient of Prob_Smart_Pricing_Tool: 46.54217738224458
# Bandwidth: 6.06, Coefficient of Prob_Smart_Pricing_Tool: 46.54217738224458
# Bandwidth: 6.16, Coefficient of Prob_Smart_Pricing_Tool: 46.72146940622465
# Bandwidth: 6.26, Coefficient of Prob_Smart_Pricing_Tool: 47.028373051309735
# Bandwidth: 6.36, Coefficient of Prob_Smart_Pricing_Tool: 47.22952250745742
# Bandwidth: 6.46, Coefficient of Prob_Smart_Pricing_Tool: 47.22952250745742
# Bandwidth: 6.56, Coefficient of Prob_Smart_Pricing_Tool: 47.351310517069344
# Bandwidth: 6.66, Coefficient of Prob_Smart_Pricing_Tool: 47.435346937917174
# Bandwidth: 6.76, Coefficient of Prob_Smart_Pricing_Tool: 47.435346937917174
# Bandwidth: 6.86, Coefficient of Prob_Smart_Pricing_Tool: 47.533865558894725
# Bandwidth: 6.96, Coefficient of Prob_Smart_Pricing_Tool: 47.673739111720025
# Bandwidth: 7.06, Coefficient of Prob_Smart_Pricing_Tool: 47.673739111720025
# Bandwidth: 7.16, Coefficient of Prob_Smart_Pricing_Tool: 47.83678665396312
# Bandwidth: 7.26, Coefficient of Prob_Smart_Pricing_Tool: 48.10749444019126
# Bandwidth: 7.36, Coefficient of Prob_Smart_Pricing_Tool: 48.10749444019126
# Bandwidth: 7.46, Coefficient of Prob_Smart_Pricing_Tool: 48.235176318720775
# Bandwidth: 7.56, Coefficient of Prob_Smart_Pricing_Tool: 48.3164846117047
# Bandwidth: 7.66, Coefficient of Prob_Smart_Pricing_Tool: 48.3164846117047
# Bandwidth: 7.76, Coefficient of Prob_Smart_Pricing_Tool: 48.3996458076525
# Bandwidth: 7.86, Coefficient of Prob_Smart_Pricing_Tool: 48.49577267635336
# Bandwidth: 7.96, Coefficient of Prob_Smart_Pricing_Tool: 48.49577267635336
# Bandwidth: 8.06, Coefficient of Prob_Smart_Pricing_Tool: 48.64142689569098
# Bandwidth: 8.16, Coefficient of Prob_Smart_Pricing_Tool: 48.895492973106855
# Bandwidth: 8.26, Coefficient of Prob_Smart_Pricing_Tool: 48.895492973106855
# Bandwidth: 8.36, Coefficient of Prob_Smart_Pricing_Tool: 49.24762069237792
# Bandwidth: 8.46, Coefficient of Prob_Smart_Pricing_Tool: 49.519943975676185
# Bandwidth: 8.56, Coefficient of Prob_Smart_Pricing_Tool: 49.519943975676185
# Bandwidth: 8.66, Coefficient of Prob_Smart_Pricing_Tool: 49.6537414553278
# Bandwidth: 8.76, Coefficient of Prob_Smart_Pricing_Tool: 49.802534948066246
# Bandwidth: 8.86, Coefficient of Prob_Smart_Pricing_Tool: 49.802534948066246
# Bandwidth: 8.96, Coefficient of Prob_Smart_Pricing_Tool: 49.97209398007968
# Bandwidth: 9.06, Coefficient of Prob_Smart_Pricing_Tool: 50.15897628455627
# Bandwidth: 9.16, Coefficient of Prob_Smart_Pricing_Tool: 50.15897628455627
# Bandwidth: 9.26, Coefficient of Prob_Smart_Pricing_Tool: 50.34195203389441
# Bandwidth: 9.36, Coefficient of Prob_Smart_Pricing_Tool: 50.586831870955635
# Bandwidth: 9.46, Coefficient of Prob_Smart_Pricing_Tool: 50.586831870955635
# Bandwidth: 9.56, Coefficient of Prob_Smart_Pricing_Tool: 50.80995358789035
# Bandwidth: 9.66, Coefficient of Prob_Smart_Pricing_Tool: 50.81324197608839
# Bandwidth: 9.76, Coefficient of Prob_Smart_Pricing_Tool: 50.818709335625584
# Bandwidth: 9.86, Coefficient of Prob_Smart_Pricing_Tool: 50.818709335625584
# Bandwidth: 9.96, Coefficient of Prob_Smart_Pricing_Tool: 50.84188062366436
# Bandwidth: 10.06, Coefficient of Prob_Smart_Pricing_Tool: 50.889207791442544

# %% [markdown]
# ## Multicollinearity Check: Variance Inflation Factor (VIF)

# %%
# Add a constant term for the intercept
X_stage_1 = add_constant(data_bandwidth[['Prob_Smart_Pricing_Tool'] + control_vars_1st])  # Add other variables as required

# Calculate VIF for each variable for stage 1
vif_data1 = pd.DataFrame()
vif_data1['variable'] = X_stage_1.columns
vif_data1['VIF'] = [variance_inflation_factor(X_stage_1.values, i) for i in range(X_stage_1.shape[1])]

print(vif_data1)

# Add a constant term for the intercept
X_stage_2 = add_constant(data_bandwidth[['Prob_Smart_Pricing_Tool'] + control_vars_2nd])  # Add other variables as required

# Calculate VIF for each variable for stage 2
vif_data2 = pd.DataFrame()
vif_data2['variable'] = X_stage_2.columns
vif_data2['VIF'] = [variance_inflation_factor(X_stage_2.values, i) for i in range(X_stage_2.shape[1])]

print(vif_data2)
# Out:
#                        variable         VIF
# 0                         const  281.700291
# 1       Prob_Smart_Pricing_Tool    1.150518
# 2                host_since_mos    1.135776
# 3          host_acceptance_rate    1.132839
# 4             host_is_superhost    1.212481
# 5              instant_bookable    1.075259
# 6           host_listings_count    1.090261
# 7        review_scores_accuracy    2.829026
# 8     review_scores_cleanliness    1.815229
# 9   review_scores_communication    2.185975
# 10       review_scores_location    1.338853
# 11          review_scores_value    2.338908
# 12            reviews_per_month    1.119962
#                   variable        VIF
# 0                    const  13.558770
# 1  Prob_Smart_Pricing_Tool   1.070021
# 2             accommodates   3.945566
# 3                 bedrooms   1.791663
# 4                     beds   3.998100
# 5                bathrooms   1.360712
# 6          amenities_count   1.233990
# 7                  weekend   1.000271
# 8         instant_bookable   1.062445

# %% [markdown]
# ## Heteroskedasticity Test: Breusch-Pagan Test

# %%
from statsmodels.stats.diagnostic import het_breuschpagan

# Run Breusch-Pagan test
bp_test = het_breuschpagan(model_2nd_stage.resid, model_2nd_stage.model.exog)
labels = ['Lagrange Multiplier statistic', 'p-value', 'f-value', 'f p-value']
print(dict(zip(labels, bp_test)))
# Out:
# {'Lagrange Multiplier statistic': 7912.133854531075, 'p-value': 0.0, 'f-value': 228.10218772491743, 'f p-value': 0.0}

# %% [markdown]
# ## Model Specification Test: Ramsey RESET Test

# %%
from statsmodels.stats.diagnostic import linear_reset

reset_test = linear_reset(model_2nd_stage)
print(reset_test)
# Out:
# <Wald test (chi2): statistic=1677.4659116226726, p-value=0.0, df_denom=2>

# %% [markdown]
# ## Normality Test of Residuals: Jarque-Bera Test

# %%
from statsmodels.stats.stattools import jarque_bera

jb_test = jarque_bera(model_2nd_stage.resid)
labels = ['Test statistic', 'p-value', 'Skewness', 'Kurtosis']
print(dict(zip(labels, jb_test)))
# Out:
# {'Test statistic': 36640.3118765268, 'p-value': 0.0, 'Skewness': 0.9817423195690069, 'Kurtosis': 5.424648552834778}
